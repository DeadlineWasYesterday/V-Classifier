# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font='Franklin Gothic Book',
        rc={
 'axes.axisbelow': False,
 'axes.edgecolor': 'lightgrey',
 'axes.facecolor': 'None',
 'axes.grid': False,
 'axes.labelcolor': 'dimgrey',
 'axes.spines.right': False,
 'axes.spines.top': False,
 'figure.facecolor': 'white',
 'lines.solid_capstyle': 'round',
 'patch.edgecolor': 'w',
 'patch.force_edgecolor': True,
 'text.color': 'dimgrey',
 'xtick.bottom': False,
 'xtick.color': 'dimgrey',
 'xtick.direction': 'out',
 'xtick.top': False,
 'ytick.color': 'dimgrey',
 'ytick.direction': 'out',
 'ytick.left': False,
 'ytick.right': False})
# sns.set_context("notebook", rc={"font.size":14,
#                                 "axes.titlesize":16,
#                                 "axes.labelsize":15})

# %%
df = pd.read_clipboard()

# %%
df = df.astype(float)

# %%
# Out:
# <a list of 57 Text major ticklabel objects>

# %%
plt.rcParams['figure.figsize'] = (40.0, 25.0)
sns.set(font_scale = 1.75)
heat = sns.heatmap(df.round(2), cmap = 'coolwarm')
#heat.set(xticklabels=[])
#heat.set_xticklabels(heat.get_xticklabels(), size = 1)
plt.xlabel('Families', fontsize = 36)
plt.ylabel('Classifiers', fontsize = 36)
plt.title('Leave-One-Family-Out Cross-Validation Results', fontsize = 40)
ttl = heat.title
ttl.set_position([.5, 2])
heat.get_figure().savefig('../heatmap9.png')

# %%
p.get_figure().savefig('../heatmap.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f4e5be0c18bf> in <module>
# ----> 1 p.get_figure().savefig('../heatmap.png')
#
# NameError: name 'p' is not defined

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams['font.family'] = "serif"

# %%
heat_map = sns.heatmap(df2.round(2), annot = True, cmap = 'coolwarm', robust = False, annot_kws={'size':16}, square=True)

# %%
sns.set(font_scale = 2)
plt.rcParams['font.size'] = 4
bg_color = (0.88,0.85,0.95)
plt.rcParams['figure.facecolor'] = bg_color
plt.rcParams['axes.facecolor'] = bg_color
fig, ax = plt.subplots(1)
p = sns.heatmap(df2.round(2),
                cmap='coolwarm',
                annot=True,
                linewidths=0.1,
                annot_kws={'size':6},
                ax=ax)
plt.xlabel('Families')
plt.ylabel('Classifiers')
ax.set_ylim((0,15))
plt.text(5,12.3, "Heat Map", fontsize = 36, color='Black', fontstyle='italic')
p.get_figure().savefig('../heatmap.png')
