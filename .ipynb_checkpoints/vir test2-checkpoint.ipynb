# %%
f = open('plus ssRNA.txt', 'r')
x = f.readlines()
f.close()

# %%
x2 = []

for i in x:
    if 'virus' in i and 'viridae' not in i:
        x2.append(i.split('-')[0][:-1])

# %%
len(x2)
# Out:
# 900

# %%
f = open('minus ssRNA.txt', 'r')
x = f.readlines()
f.close()

# %%
x3 = []

for i in x:
    if 'virus' in i and 'viridae' not in i:
        x3.append(i.split('-')[0][:-1])

# %%
x3[-5]
# Out:
# ['ViRAD (-)\n',
#  'Virus (re-)annotation database\n',
#  "Note: The alignment 'depth' is encoded in the link: (M) - Genome map only (no alignment produced). (?.?) - Synonymous site conservation and coding potential plots produced; the number '?.?' gives an indication of the alignment 'depth' and therefore statistical power (essentially it is the mean z-score that would be obtained for 25-codon window with 100% suppression of synonymous substitutions, prior to correction for multiple testing). Alignments with scores < 3 are virtually useless for the synplot2 analysis but some of these may still provide useful MLOGD results.\n",
#  '\n',
#  '\n',
#  'Arenaviridae -\n',
#  '\n',
#  'Boa arenavirus NL - Seg-L (4.5), Seg-S (4.0)\n',
#  'CAS virus - Seg-L (M), Seg-S (M)\n',
#  'Golden Gate virus - Seg-L (4.2), Seg-S (M)\n',
#  'University of Helsinki virus - Seg-L (2.7), Seg-S (M)\n',
#  '\n',
#  'Arenaviridae - Arenavirus\n',
#  '\n',
#  'Lujo virus - Seg-L (M), Seg-S (M)\n',
#  'Luna virus - Seg-L (5.6), Seg-S (12.9)\n',
#  '\n',
#  'Arenaviridae - Arenavirus New world arenaviruses\n',
#  '\n',
#  'Allpahuayo virus - Seg-L (M), Seg-S (8.7)\n',
#  'Amapari virus - Seg-L (0.2), Seg-S (7.3)\n',
#  'Bear Canyon virus - Seg-L (2.5), Seg-S (9.6)\n',
#  'Chapare virus - Seg-L (M), Seg-S (4.6)\n',
#  'Cupixi virus - Seg-L (M), Seg-S (M)\n',
#  'Flexal virus - Seg-L (M), Seg-S (8.7)\n',
#  'Guanarito virus - Seg-L (0.7), Seg-S (8.2)\n',
#  'Junin virus - Seg-L (2.3), Seg-S (7.4)\n',
#  'Latino virus - Seg-L (M), Seg-S (4.7)\n',
#  'Machupo virus - Seg-L (3.2), Seg-S (8.2)\n',
#  'Oliveros virus - Seg-L (M), Seg-S (4.7)\n',
#  'Parana virus - Seg-L (M), Seg-S (8.3)\n',
#  'Pichinde virus - Seg-L (3.5), Seg-S (8.6)\n',
#  'Pirital virus - Seg-L (1.8), Seg-S (9.2)\n',
#  'Sabia virus - Seg-L (M), Seg-S (4.6)\n',
#  'Tacaribe virus - Seg-L (M), Seg-S (6.7)\n',
#  'Tamiami virus - Seg-L (2.4), Seg-S (4.2)\n',
#  'Whitewater Arroyo virus - Seg-L (4.4), Seg-S (10.2)\n',
#  '\n',
#  'Arenaviridae - Arenavirus Old world arenaviruses\n',
#  '\n',
#  'Ippy virus - Seg-L (M), Seg-S (M)\n',
#  'Lassa virus - Seg-L (8.5), Seg-S (14.1)\n',
#  'Lunk virus NKS-1 - Seg-L (M), Seg-S (14.6)\n',
#  'Lymphocytic choriomeningitis virus - Seg-L (12.4), Seg-S (14.8)\n',
#  'Merino Walk virus - Seg-L (M), Seg-S (M)\n',
#  'Mobala virus - Seg-L (M), Seg-S (12.3)\n',
#  'Mopeia Lassa virus reassortant 29 - Seg-L (M), Seg-S (14.1)\n',
#  'Mopeia virus AN20410 - Seg-L (M), Seg-S (13.9)\n',
#  'Morogoro virus - Seg-L (M), Seg-S (12.8)\n',
#  '\n',
#  'Bunyaviridae -\n',
#  '\n',
#  'Lone Star virus - Seg-L (M), Seg-M (M), Seg-S (M)\n',
#  '\n',
#  'Bunyaviridae - Hantavirus\n',
#  '\n',
#  'Andes virus - Seg-L (17.7), Seg-M (16.1), Seg-S (24.2)\n',
#  'Dobrava-Belgrade virus - Seg-L (14.2), Seg-M (18.1), Seg-S (17.6)\n',
#  'Hantaan virus - Seg-L (14.2), Seg-M (18.1), Seg-S (17.7)\n',
#  'Hantavirus Z10 - Seg-L (14.2), Seg-M (18.1), Seg-S (17.6)\n',
#  'Puumala virus - Seg-L (17.9), Seg-M (14.0), Seg-S (21.9)\n',
#  'Seoul virus - Seg-L (14.2), Seg-M (18.0), Seg-S (18.5)\n',
#  'Sin Nombre virus - Seg-L (17.9), Seg-M (17.5), Seg-S (21.4)\n',
#  'Thottapalayam virus - Seg-L (5.1), Seg-M (4.1), Seg-S (4.4)\n',
#  'Tula virus - Seg-L (17.9), Seg-M (14.0), Seg-S (24.2)\n',
#  '\n',
#  'Bunyaviridae - Nairovirus\n',
#  '\n',
#  'Crimean-Congo hemorrhagic fever virus - Seg-L (9.1), Seg-M (10.0), Seg-S (10.3)\n',
#  'Dugbe virus - Seg-L (4.6), Seg-M (M), Seg-S (5.0)\n',
#  '\n',
#  'Bunyaviridae - Orthobunyavirus\n',
#  '\n',
#  'Aino virus - Seg-L (5.9), Seg-M (5.6), Seg-S (9.6)\n',
#  'Akabane virus - Seg-L (5.1), Seg-M (5.8), Seg-S (9.7)\n',
#  'Brazoran virus - Seg-L (M), Seg-M (M), Seg-S (M)\n',
#  'Bunyamwera virus - Seg-L (8.8), Seg-M (4.6), Seg-S (10.9)\n',
#  'Cat Que virus - Seg-L (7.5), Seg-M (6.5), Seg-S (10.8)\n',
#  'La Crosse virus - Seg-L (11.2), Seg-M (11.9), Seg-S (11.9)\n',
#  'Murrumbidgee virus - Seg-L (M), Seg-M (M), Seg-S (M)\n',
#  'Oropouche virus - Seg-L (5.8), Seg-M (1.2), Seg-S (11.9)\n',
#  'Sathuperi virus - Seg-L (4.9), Seg-M (5.1), Seg-S (9.8)\n',
#  'Shamonda virus - Seg-L (4.9), Seg-M (2.9), Seg-S (9.9)\n',
#  'Simbu virus - Seg-L (M), Seg-M (M), Seg-S (9.6)\n',
#  '\n',
#  'Bunyaviridae - Phlebovirus\n',
#  '\n',
#  'Aguacate virus - Seg-L (6.1), Seg-M (M), Seg-S (6.1)\n',
#  'Arumowot virus - Seg-L (4.7), Seg-M (M), Seg-S (M)\n',
#  'Candiru virus - Seg-L (9.8), Seg-M (M), Seg-S (9.5)\n',
#  'Razdan virus - Seg-L (6.7), Seg-M (7.0), Seg-S (6.3)\n',
#  'Rift Valley fever virus - Seg-L (4.7), Seg-M (5.0), Seg-S (6.7)\n',
#  'Sandfly fever Naples virus - Seg-L (9.3), Seg-M (4.6), Seg-S (7.7)\n',
#  'Sandfly fever Turkey virus - Seg-L (M), Seg-M (2.4), Seg-S (5.0)\n',
#  'SFTS virus HB29 - Seg-L (5.9), Seg-M (5.6), Seg-S (8.7)\n',
#  'Uukuniemi virus - Seg-L (9.1), Seg-M (7.1), Seg-S (M)\n',
#  '\n',
#  'Bunyaviridae - Tospovirus\n',
#  '\n',
#  'Bean necrotic mosaic virus - Seg-L (M), Seg-M (M), Seg-S (M)\n',
#  'Capsicum chlorosis virus - Seg-L (8.8), Seg-M (7.5), Seg-S (10.3)\n',
#  'Groundnut bud necrosis virus - Seg-L (8.8), Seg-M (7.4), Seg-S (9.9)\n',
#  'Groundnut ringspot and Tomato chlorotic spot virus reassortant - Seg-L (6.0), Seg-M (7.3), Seg-S (7.8)\n',
#  'Impatiens necrotic spot virus - Seg-L (1.1), Seg-M (1.4), Seg-S (1.7)\n',
#  'Melon yellow spot virus - Seg-L (7.7), Seg-M (1.7), Seg-S (2.7)\n',
#  'Tomato spotted wilt virus - Seg-L (5.9), Seg-M (7.3) (replacement RefSeq), Seg-M (M), Seg-S (7.7)\n',
#  'Tomato zonate spot virus - Seg-L (8.2), Seg-M (5.6), Seg-S (3.7)\n',
#  'Watermelon silver mottle virus - Seg-L (8.8), Seg-M (7.3), Seg-S (9.7)\n',
#  '\n',
#  'Emaravirus\n',
#  '\n',
#  'European mountain ash ringspot-associated virus - RNA1 (M), RNA2 (M), RNA3 (6.1), RNA4 (M)\n',
#  'Rose rosette virus - RNA1 (M), RNA2 (M), RNA3 (2.4), RNA4 (2.5)\n',
#  '\n',
#  'Mononegavirales -\n',
#  '\n',
#  'Midway virus - (M)\n',
#  'Nyamanini virus - (M)\n',
#  '\n',
#  'Mononegavirales - Bornaviridae - Bornavirus\n',
#  '\n',
#  'Borna disease virus - (4.7)\n',
#  '\n',
#  'Mononegavirales - Filoviridae -\n',
#  '\n',
#  'Lloviu virus - (M)\n',
#  '\n',
#  'Mononegavirales - Filoviridae - Ebolavirus\n',
#  '\n',
#  'Bundibugyo ebolavirus - (5.8)\n',
#  'Ebola virus - Mayinga Zaire 1976 - (5.8)\n',
#  'Reston ebolavirus - (1.7)\n',
#  'Sudan ebolavirus - (1.9)\n',
#  'Tai Forest ebolavirus - (5.8)\n',
#  '\n',
#  'Mononegavirales - Filoviridae - Marburgvirus\n',
#  '\n',
#  'Marburg marburgvirus - (4.7)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae -\n',
#  '\n',
#  'Nariva virus - (M)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae - Paramyxovirinae -\n',
#  '\n',
#  'Beilong virus - (4.6)\n',
#  'J-virus - (M)\n',
#  'Mossman virus - (M)\n',
#  'Tupaia paramyxovirus - (M)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae - Paramyxovirinae - Avulavirus\n',
#  '\n',
#  'Avian paramyxovirus 4 - (4.1)\n',
#  'Avian paramyxovirus 6 - (5.2)\n',
#  'Goose paramyxovirus SF02 - (13.9)\n',
#  'Newcastle disease virus B1 - (13.8)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae - Paramyxovirinae - Ferlavirus\n',
#  '\n',
#  'Fer-de-Lance paramyxovirus - (M)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae - Paramyxovirinae - Henipavirus\n',
#  '\n',
#  'Hendra virus - (5.0)\n',
#  'Nipah virus - (5.0)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae - Paramyxovirinae - Morbillivirus\n',
#  '\n',
#  'Canine distemper virus - (5.4)\n',
#  'Dolphin morbillivirus - (M)\n',
#  'Measles virus - (6.1)\n',
#  'Peste-des-petits-ruminants virus - (3.2)\n',
#  'Rinderpest virus strain Kabete O - (5.5)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae - Paramyxovirinae - Respirovirus\n',
#  '\n',
#  'Bovine parainfluenza virus 3 - (7.2)\n',
#  'Human parainfluenza virus 1 - (6.1)\n',
#  'Human parainfluenza virus 3 - (7.1)\n',
#  'Sendai virus - (6.1)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae - Paramyxovirinae - Rubulavirus\n',
#  '\n',
#  'Human parainfluenza virus 2 - (1.8)\n',
#  'Human parainfluenza virus 4a - (3.2)\n',
#  'Mapuera virus - (M)\n',
#  'Menangle virus - (1.8)\n',
#  'Mumps virus - (6.0)\n',
#  'Parainfluenza virus 5 - (1.9)\n',
#  'Porcine rubulavirus - (M)\n',
#  'Simian virus 41 - (M)\n',
#  'Tioman virus - (M)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae - Pneumovirinae - Metapneumovirus\n',
#  '\n',
#  'Avian metapneumovirus - (2.2)\n',
#  'Human metapneumovirus - (7.1)\n',
#  '\n',
#  'Mononegavirales - Paramyxoviridae - Pneumovirinae - Pneumovirus\n',
#  '\n',
#  'Bovine respiratory syncytial virus - (7.0)\n',
#  'Human respiratory syncytial virus - (7.0)\n',
#  'Pneumonia virus of mice J3666 - (1.5)\n',
#  'Respiratory syncytial virus - (6.9)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae -\n',
#  '\n',
#  'Ngaingan virus - (M)\n',
#  'Siniperca chuatsi rhabdovirus - (1.6)\n',
#  'Tupaia virus - (M)\n',
#  'Wongabel virus - (M)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae - Cytorhabdovirus\n',
#  '\n',
#  'Lettuce necrotic yellows virus - (M)\n',
#  'Lettuce yellow mottle virus - (M)\n',
#  'Northern cereal mosaic virus - (2.2)\n',
#  'Persimmon virus A - (M)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae - Ephemerovirus\n',
#  '\n',
#  'Bovine ephemeral fever virus - (M)\n',
#  'Kotonkan virus - (M)\n',
#  'Obodhiang virus - (M)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae - Lyssavirus\n',
#  '\n',
#  'Aravan virus - (19.5)\n',
#  'Australian bat lyssavirus - (18.9)\n',
#  'Duvenhage virus - (18.7)\n',
#  'European bat lyssavirus 1 - (19.5)\n',
#  'European bat lyssavirus 2 - (19.0)\n',
#  'Ikoma lyssavirus - (M)\n',
#  'Irkut virus - (19.6)\n',
#  'Lagos bat virus - (13.5)\n',
#  'Mokola virus - (10.1)\n',
#  'Rabies virus - (18.9)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae - Novirhabdovirus\n',
#  '\n',
#  'Hirame rhabdovirus - (4.7)\n',
#  'Infectious hematopoietic necrosis virus - (4.7)\n',
#  'Snakehead virus - (M)\n',
#  'Viral hemorrhagic septicemia virus Fil3 - (4.3)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae - Nucleorhabdovirus\n',
#  '\n',
#  'Maize fine streak virus - (M)\n',
#  'Maize Iranian mosaic virus - (M)\n',
#  'Maize mosaic virus - (M)\n',
#  'Potato yellow dwarf virus - (M)\n',
#  'Rice yellow stunt virus - (0.8)\n',
#  'Sonchus yellow net virus - (0.1)\n',
#  'Taro vein chlorosis virus - (M)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae - Perhabdovirus\n',
#  '\n',
#  'Eel virus European X - (1.1)\n',
#  'Perch rhabdovirus - (M)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae - Sigmavirus\n',
#  '\n',
#  'Drosophila melanogaster sigmavirus AP30 - (2.5)\n',
#  'Drosophila obscura sigmavirus 10A - (M)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae - Tibrovirus\n',
#  '\n',
#  'Tibrogargan virus - (M)\n',
#  '\n',
#  'Mononegavirales - Rhabdoviridae - Vesiculovirus\n',
#  '\n',
#  'American bat vesiculovirus TFFN-2013 - (M)\n',
#  'Chandipura virus - (6.0)\n',
#  'Isfahan virus - (M)\n',
#  'Spring viraemia of carp virus - (6.7)\n',
#  'Vesicular stomatitis Indiana virus - (5.1)\n',
#  '\n',
#  'Ophioviridae - Ophiovirus\n',
#  '\n',
#  'Citrus psorosis virus - RNA1 (4.1), RNA2 (4.2), RNA3 (3.7)\n',
#  'Lettuce ring necrosis virus - RNA1 (M), RNA2 (M), RNA3 (M), RNA4 (M)\n',
#  'Mirafiori lettuce big-vein virus - RNA1 (M), RNA2 (1.4), RNA3 (4.3), RNA4 (M)\n',
#  '\n',
#  'Orthomyxoviridae - Influenzavirus A\n',
#  '\n',
#  'Influenza A virus A-Puerto Rico-8-1934 H1N1 - Seg-1 (18.7), Seg-2 (18.1), Seg-3 (14.8), Seg-4 (10.0), Seg-5 (14.8), Seg-6 (11.1), Seg-7 (12.6), Seg-8 (12.4)\n',
#  '\n',
#  'Orthomyxoviridae - Influenzavirus B\n',
#  '\n',
#  'Influenza B virus - RNA1 (6.9), RNA2 (7.1), RNA3 (6.3), RNA4 (6.6), RNA5 (6.8), RNA6 (5.7), RNA7 (6.2), RNA8 (5.2)\n',
#  '\n',
#  'Orthomyxoviridae - Influenzavirus C\n',
#  '\n',
#  'Influenza C virus C-Ann Arbor-1-50 - Seg-1 (1.7), Seg-2 (1.7), Seg-3 (1.6), Seg-4 (5.4), Seg-5 (2.9), Seg-6 (4.3), Seg-7 (3.5)\n',
#  '\n',
#  'Orthomyxoviridae - Isavirus\n',
#  '\n',
#  'Infectious salmon anemia virus - Seg-1 (5.0), Seg-2 (4.9), Seg-3 (5.5), Seg-4 (7.1), Seg-5 (6.1), Seg-6 (5.2), Seg-7 (3.0) (replacement RefSeq), Seg-7 (3.0), Seg-8 (1.7)\n',
#  '\n',
#  'Orthomyxoviridae - Thogotovirus\n',
#  '\n',
#  'Thogoto virus - Seg-1 (M), Seg-2 (M), Seg-3 (M), Seg-4 (M), Seg-5 (M), Seg-6 (4.9)\n',
#  '\n',
#  'Tenuivirus\n',
#  '\n',
#  'Rice grassy stunt virus - RNA1 (0.5), RNA2 (1.4), RNA3 (2.1), RNA4 (1.3), RNA5 (2.4), RNA6 (1.8)\n',
#  'Rice stripe virus - RNA1 (5.1), RNA2 (5.4), RNA3 (8.6), RNA4 (8.3)\n',
#  '\n',
#  'Varicosavirus\n',
#  '\n',
#  'Lettuce big-vein associated virus - RNA1 (1.9), RNA2 (1.8)\n',
#  '\n',
#  'Unclassified viruses\n',
#  '\n',
#  'Orchid fleck virus - RNA1 (2.9), RNA2 (3.2)\n',
#  '\n']

# %%
import pandas as pd

df2 = pd.read_csv('ICTV 2018b.v2.csv')

# %%
df2.head()
# Out:
#    Sort      Realm  Subrealm  Kingdom  Subkingdom           Phylum  \
# 0     1  Riboviria       NaN      NaN         NaN  Negarnaviricota
# 1     2  Riboviria       NaN      NaN         NaN  Negarnaviricota
# 2     3  Riboviria       NaN      NaN         NaN  Negarnaviricota
# 3     4  Riboviria       NaN      NaN         NaN  Negarnaviricota
# 4     5  Riboviria       NaN      NaN         NaN  Negarnaviricota
#
#          Subphylum             Class  Subclass      Order  ...      Genus  \
# 0  Haploviricotina  Chunqiuviricetes       NaN  Muvirales  ...  Yingvirus
# 1  Haploviricotina  Chunqiuviricetes       NaN  Muvirales  ...  Yingvirus
# 2  Haploviricotina  Chunqiuviricetes       NaN  Muvirales  ...  Yingvirus
# 3  Haploviricotina  Chunqiuviricetes       NaN  Muvirales  ...  Yingvirus
# 4  Haploviricotina  Chunqiuviricetes       NaN  Muvirales  ...  Yingvirus
#
#   Subgenus              Species Type Species? Genome Composition Last Change  \
# 0      NaN     Beihai yingvirus             0           ssRNA(-)      Moved,
# 1      NaN  Charybdis yingvirus             0           ssRNA(-)      Moved,
# 2      NaN      Hubei yingvirus             0           ssRNA(-)      Moved,
# 3      NaN     Sanxia yingvirus             0           ssRNA(-)      Moved,
# 4      NaN      Shahe yingvirus             0           ssRNA(-)      Moved,
#
#    MSL of Last Change     Proposal for Last Change      Taxon History URL  \
# 0                  34  2017.006G.A.v3.Riboviria.zip  ICTVonline=201856030
# 1                  34  2017.006G.A.v3.Riboviria.zip  ICTVonline=201856031
# 2                  34  2017.006G.A.v3.Riboviria.zip  ICTVonline=201856032
# 3                  34  2017.006G.A.v3.Riboviria.zip  ICTVonline=201856033
# 4                  34  2017.006G.A.v3.Riboviria.zip  ICTVonline=201856034
#
#    Unnamed: 22
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 23 columns]
