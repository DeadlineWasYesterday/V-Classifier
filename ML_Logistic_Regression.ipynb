# %% [markdown]
# # Load libraries

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # All features

# %%
df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam']],
                 pd.read_csv('drive/My Drive/ppnnw5.csv').iloc[:,10:],
                 pd.read_csv('drive/My Drive/ppnnw6.csv').iloc[:,10:]], axis = 1)

df1 = df1.loc[df1['die'] == 'no']
df1['Gen'] = 1
df2 = pd.concat([pd.read_csv('drive/My Drive/h1w5.csv')[['die']],
                 pd.read_csv('drive/My Drive/h1w5.csv').iloc[:, 5:], 
                 pd.read_csv('drive/My Drive/h1w6p1.csv').iloc[:,5:],
                 pd.read_csv('drive/My Drive/h1w6p2.csv').iloc[:,5:]], axis = 1)
df2 = df2.loc[df2['die'] == 'no']
df2['Gen'] = 0

data = pd.concat([df1, df2], axis = 0).reset_index(drop = True)

# %% [markdown]
# Model performance with all features

# %%
temp = []
for i in range(5):
  #Splitting features and labels
  X = data.iloc[:, 3:].values.astype(float)
  y = data.iloc[:, 0].values.astype(float)

  # Splitting the dataset into the Training set and Test set
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

  # Feature Scaling
  sc = StandardScaler()
  X_train = sc.fit_transform(X_train)
  X_test = sc.transform(X_test)

  ### Training the decision tree model on the Training set
  classifier = LogisticRegression(max_iter = 2000)
  classifier.fit(X_train, y_train)

  # Predicting the Test set results
  y_pred = classifier.predict(X_test)

  # Making the Confusion Matrix
  cm = confusion_matrix(y_test, y_pred)

  #evaluation
  cv_bin = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1')
  cv_mac = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1_macro')
  f1bin = f1_score(y_test, y_pred, average='binary')
  f1mac = f1_score(y_test, y_pred, average='macro')

  #AUC
  acc = metrics.accuracy_score(y_test, y_pred)
  y_pred_proba = classifier.predict_proba(X_test)[::,1]
  fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
  auc = metrics.roc_auc_score(y_test, y_pred_proba)
  plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
  plt.legend(loc=4)
  plt.show()

  temp.append((cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
  print('correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** cv_bin mean: %f ** cv_bin std: %f ** cv_mac mean: %f ** cv_mac std: %f ** f1bin: %f ** f1mac: %f' 
        % (cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
  
lrallf = pd.DataFrame(temp, columns = ['TP', 'FP', 'TN', 'FN', 'cv_bin mean', 'cv_bin std', 'cv_mac mean', 'cv_man std', 'f1bin', 'f1mac'])
# Out:
# correct/TP: 1056 ** FP: 4 **  TN: 3838 ** FN: 0 ** cv_bin mean: 0.997716 ** cv_bin std: 0.001954 ** cv_mac mean: 0.998557 ** cv_mac std: 0.001235 ** f1bin: 0.998110 ** f1mac: 0.998794
# correct/TP: 1049 ** FP: 4 **  TN: 3844 ** FN: 1 ** cv_bin mean: 0.997559 ** cv_bin std: 0.001668 ** cv_mac mean: 0.998457 ** cv_mac std: 0.001054 ** f1bin: 0.997622 ** f1mac: 0.998486
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-82c359515995> in <module>()
#      25   #evaluation
#      26   cv_bin = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1')
# ---> 27   cv_mac = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1_macro')
#      28   f1bin = f1_score(y_test, y_pred, average='binary')
#      29   f1mac = f1_score(y_test, y_pred, average='macro')
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     388                                 fit_params=fit_params,
#     389                                 pre_dispatch=pre_dispatch,
# --> 390                                 error_score=error_score)
#     391     return cv_results['test_score']
#     392
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     234             return_times=True, return_estimator=return_estimator,
#     235             error_score=error_score)
# --> 236         for train, test in cv.split(X, y, groups))
#     237
#     238     zipped_scores = list(zip(*scores))
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1599                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1600                       sample_weight=sample_weight)
# -> 1601             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1602
#    1603         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     934                 func, w0, method="L-BFGS-B", jac=True,
#     935                 args=(X, target, 1. / C, sample_weight),
# --> 936                 options={"iprint": iprint, "gtol": tol, "maxiter": max_iter}
#     937             )
#     938             n_iter_i = _check_optimize_result(
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     elif meth == 'l-bfgs-b':
#     609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in _logistic_loss_and_grad(w, X, y, alpha, sample_weight)
#     127     z0 = sample_weight * (z - 1) * y
#     128
# --> 129     grad[:n_features] = safe_sparse_dot(X.T, z0) + alpha * w
#     130
#     131     # Case where we fit the intercept.
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     149             ret = np.dot(a, b)
#     150     else:
# --> 151         ret = a @ b
#     152
#     153     if (sparse.issparse(a) and sparse.issparse(b)
#
# KeyboardInterrupt:

# %%
dtallf.to_clipboard(index = False)

# %% [markdown]
# LOFO CV

# %%
temp = []

df2test = df2.sample(frac = 0.3)
df2train = df2[~df2.index.isin(df2test.index)]

for fam in set(df1['Fam'].to_list()):
    df1test = df1.loc[df1['Fam'] == fam]
    df1train = df1.loc[~(df1['Fam'] == fam)]
    df1train = df1train.loc[df1train['die'] == 'no']
    
    X_train = pd.concat([df1train.iloc[:,3:], df2train.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_train = pd.concat([df1train.iloc[:,0], df2train.iloc[:,-1]], axis = 0).reset_index(drop = True)

    X_test = pd.concat([df1test.iloc[:,3:], df2test.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_test = pd.concat([df1test.iloc[:,0], df2test.iloc[:,-1]], axis = 0).reset_index(drop = True)
    
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    # Fitting Random Forest Classification to the Training set
    classifier = LogisticRegression(max_iter = 2000)
    classifier.fit(X_train, y_train)
    
    # Predicting the Test set results
    y_pred = classifier.predict(X_test)
    
    # Making the Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    #evaluation
    f1bin = f1_score(y_test, y_pred, average='binary')
    f1mac = f1_score(y_test, y_pred, average='macro')
    
    temp.append((fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))

    print('Fam: %s ** total: %d ** correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** f1bin: %f ** f1mac: %f' 
          % (fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))
  
lrlofocv_allf = pd.DataFrame(temp, columns = ['Fam', 'Total', 'Correct/TP', 'FP', 'TN', 'FN', 'f1bin', 'f1mac'])
# Out:
# Fam: hepeviridae ** total: 30 ** correct/TP: 30 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.869565 ** f1mac: 0.934298
# Fam: paramyxoviridae ** total: 158 ** correct/TP: 158 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.972308 ** f1mac: 0.985669
# Fam: peribunyaviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: chuviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: tobaniviridae ** total: 16 ** correct/TP: 16 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.780488 ** f1mac: 0.889759
# Fam: bornaviridae ** total: 24 ** correct/TP: 24 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.842105 ** f1mac: 0.920568
# Fam: gammaflexiviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: nyamiviridae ** total: 6 ** correct/TP: 3 ** FP: 10 **  TN: 4633 ** FN: 3 ** f1bin: 0.315789 ** f1mac: 0.657194
# Fam: sunviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: coronaviridae ** total: 258 ** correct/TP: 258 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.982857 ** f1mac: 0.990944
# Fam: tymoviridae ** total: 80 ** correct/TP: 79 ** FP: 10 **  TN: 4633 ** FN: 1 ** f1bin: 0.934911 ** f1mac: 0.966863
# Fam: nodaviridae ** total: 20 ** correct/TP: 20 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.816327 ** f1mac: 0.907678
# Fam: flaviviridae ** total: 340 ** correct/TP: 324 ** FP: 7 **  TN: 4636 ** FN: 16 ** f1bin: 0.965723 ** f1mac: 0.981624
# Fam: arteriviridae ** total: 48 ** correct/TP: 48 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.914286 ** f1mac: 0.956658
# Fam: leviviridae ** total: 24 ** correct/TP: 24 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.842105 ** f1mac: 0.920568
# Fam: bromoviridae ** total: 30 ** correct/TP: 30 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.869565 ** f1mac: 0.934298
# Fam: marnaviridae ** total: 20 ** correct/TP: 20 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.816327 ** f1mac: 0.907678
# Fam: artoviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: mononiviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: deltaflexiviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: kitaviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: endornaviridae ** total: 58 ** correct/TP: 58 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.928000 ** f1mac: 0.963515
# Fam: mymonaviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: tombusviridae ** total: 132 ** correct/TP: 132 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.967033 ** f1mac: 0.983031
# Fam: fimoviridae ** total: 8 ** correct/TP: 8 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.640000 ** f1mac: 0.819515
# Fam: filoviridae ** total: 24 ** correct/TP: 24 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.842105 ** f1mac: 0.920568
# Fam: carmotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: closteroviridae ** total: 90 ** correct/TP: 90 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.952381 ** f1mac: 0.975705
# Fam: virgaviridae ** total: 82 ** correct/TP: 82 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.947977 ** f1mac: 0.973503
# Fam: pneumoviridae ** total: 24 ** correct/TP: 24 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.842105 ** f1mac: 0.920568
# Fam: roniviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: secoviridae ** total: 36 ** correct/TP: 36 ** FP: 11 **  TN: 4632 ** FN: 0 ** f1bin: 0.867470 ** f1mac: 0.933142
# Fam: barnaviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: alvernaviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: hantaviridae ** total: 12 ** correct/TP: 12 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.727273 ** f1mac: 0.863151
# Fam: mesoniviridae ** total: 20 ** correct/TP: 20 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.816327 ** f1mac: 0.907678
# Fam: astroviridae ** total: 104 ** correct/TP: 104 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.958525 ** f1mac: 0.978778
# Fam: picornaviridae ** total: 780 ** correct/TP: 773 ** FP: 7 **  TN: 4636 ** FN: 7 ** f1bin: 0.991026 ** f1mac: 0.994759
# Fam: potyviridae ** total: 340 ** correct/TP: 340 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.986938 ** f1mac: 0.992984
# Fam: betaflexiviridae ** total: 220 ** correct/TP: 220 ** FP: 10 **  TN: 4633 ** FN: 0 ** f1bin: 0.977778 ** f1mac: 0.988350
# Fam: togaviridae ** total: 74 ** correct/TP: 74 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.942675 ** f1mac: 0.970853
# Fam: solemoviridae ** total: 38 ** correct/TP: 38 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.894118 ** f1mac: 0.946574
# Fam: luteoviridae ** total: 100 ** correct/TP: 100 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.956938 ** f1mac: 0.977984
# Fam: polycipiviridae ** total: 10 ** correct/TP: 10 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.689655 ** f1mac: 0.844343
# Fam: aspiviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: alphaflexiviridae ** total: 110 ** correct/TP: 110 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.960699 ** f1mac: 0.979864
# Fam: hypoviridae ** total: 24 ** correct/TP: 24 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.842105 ** f1mac: 0.920568
# Fam: alphatetraviridae ** total: 8 ** correct/TP: 8 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.640000 ** f1mac: 0.819515
# Fam: dicistroviridae ** total: 40 ** correct/TP: 40 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.898876 ** f1mac: 0.948953
# Fam: matonaviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: caliciviridae ** total: 320 ** correct/TP: 320 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.986133 ** f1mac: 0.992581
# Fam: narnaviridae ** total: 72 ** correct/TP: 70 ** FP: 10 **  TN: 4633 ** FN: 2 ** f1bin: 0.921053 ** f1mac: 0.959880
# Fam: benyviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: rhabdoviridae ** total: 212 ** correct/TP: 212 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.979215 ** f1mac: 0.989122
# Fam: permutotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: iflaviridae ** total: 74 ** correct/TP: 74 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.942675 ** f1mac: 0.970853
# Fam: nairoviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361

# %%
lrlofocv_allf
# Out:
#                     Fam  Total  Correct/TP  FP    TN  FN     f1bin     f1mac
# 0           hepeviridae     30          30   9  4634   0  0.869565  0.934298
# 1       paramyxoviridae    158         158   9  4634   0  0.972308  0.985669
# 2      peribunyaviridae      4           4   9  4634   0  0.470588  0.734809
# 3            chuviridae      4           4   9  4634   0  0.470588  0.734809
# 4         tobaniviridae     16          16   9  4634   0  0.780488  0.889759
# 5          bornaviridae     24          24   9  4634   0  0.842105  0.920568
# 6     gammaflexiviridae      2           2   9  4634   0  0.307692  0.653361
# 7          nyamiviridae      6           3  10  4633   3  0.315789  0.657194
# 8            sunviridae      2           2   9  4634   0  0.307692  0.653361
# 9         coronaviridae    258         258   9  4634   0  0.982857  0.990944
# 10          tymoviridae     80          79  10  4633   1  0.934911  0.966863
# 11          nodaviridae     20          20   9  4634   0  0.816327  0.907678
# 12         flaviviridae    340         324   7  4636  16  0.965723  0.981624
# 13        arteriviridae     48          48   9  4634   0  0.914286  0.956658
# 14          leviviridae     24          24   9  4634   0  0.842105  0.920568
# 15         bromoviridae     30          30   9  4634   0  0.869565  0.934298
# 16         marnaviridae     20          20   9  4634   0  0.816327  0.907678
# 17          artoviridae      2           2   9  4634   0  0.307692  0.653361
# 18        mononiviridae      2           2   9  4634   0  0.307692  0.653361
# 19    deltaflexiviridae      4           4   9  4634   0  0.470588  0.734809
# 20          kitaviridae      2           2   9  4634   0  0.307692  0.653361
# 21       endornaviridae     58          58   9  4634   0  0.928000  0.963515
# 22        mymonaviridae      2           2   9  4634   0  0.307692  0.653361
# 23        tombusviridae    132         132   9  4634   0  0.967033  0.983031
# 24          fimoviridae      8           8   9  4634   0  0.640000  0.819515
# 25          filoviridae     24          24   9  4634   0  0.842105  0.920568
# 26    carmotetraviridae      2           2   9  4634   0  0.307692  0.653361
# 27      closteroviridae     90          90   9  4634   0  0.952381  0.975705
# 28         virgaviridae     82          82   9  4634   0  0.947977  0.973503
# 29        pneumoviridae     24          24   9  4634   0  0.842105  0.920568
# 30          roniviridae      4           4   9  4634   0  0.470588  0.734809
# 31          secoviridae     36          36  11  4632   0  0.867470  0.933142
# 32         barnaviridae      2           2   9  4634   0  0.307692  0.653361
# 33       alvernaviridae      2           2   9  4634   0  0.307692  0.653361
# 34         hantaviridae     12          12   9  4634   0  0.727273  0.863151
# 35        mesoniviridae     20          20   9  4634   0  0.816327  0.907678
# 36         astroviridae    104         104   9  4634   0  0.958525  0.978778
# 37       picornaviridae    780         773   7  4636   7  0.991026  0.994759
# 38          potyviridae    340         340   9  4634   0  0.986938  0.992984
# 39     betaflexiviridae    220         220  10  4633   0  0.977778  0.988350
# 40          togaviridae     74          74   9  4634   0  0.942675  0.970853
# 41        solemoviridae     38          38   9  4634   0  0.894118  0.946574
# 42         luteoviridae    100         100   9  4634   0  0.956938  0.977984
# 43      polycipiviridae     10          10   9  4634   0  0.689655  0.844343
# 44          aspiviridae      4           4   9  4634   0  0.470588  0.734809
# 45    alphaflexiviridae    110         110   9  4634   0  0.960699  0.979864
# 46          hypoviridae     24          24   9  4634   0  0.842105  0.920568
# 47    alphatetraviridae      8           8   9  4634   0  0.640000  0.819515
# 48      dicistroviridae     40          40   9  4634   0  0.898876  0.948953
# 49        matonaviridae      4           4   9  4634   0  0.470588  0.734809
# 50        caliciviridae    320         320   9  4634   0  0.986133  0.992581
# 51         narnaviridae     72          70  10  4633   2  0.921053  0.959880
# 52          benyviridae      2           2   9  4634   0  0.307692  0.653361
# 53        rhabdoviridae    212         212   9  4634   0  0.979215  0.989122
# 54  permutotetraviridae      2           2   9  4634   0  0.307692  0.653361
# 55          iflaviridae     74          74   9  4634   0  0.942675  0.970853
# 56         nairoviridae      2           2   9  4634   0  0.307692  0.653361

# %% [markdown]
# ## Model performance with 194 features

# %%
l =    ['CAATCG', 'GGTA', 'GTTGA', 'CATACG', 'TGAT', 'GTCGAA', 'CCAATT', 'TGTCGA', 'GTTGAC', 
        'CGGTTA', 'CGATA', 'TAGCGT', 'AAAAAA', 'GGTTGA', 'AAAAA', 'CAAT', 'CGTCAA', 'CGGTAA', 
        'CGTTGA', 'CAAC', 'ACCAAT', 'TTGACG', 'TCAATC', 'GTTG', 'CAATTG', 'CGCAAT', 'GGTT', 
        'TTGTCG', 'TCAA', 'CCAAT', 'ATACGC', 'CGATAG', 'TTGA', 'CATCAA', 'GTTGAT', 'ATACGG', 
        'CGATC', 'GTTGGT', 'GATC', 'CCGATA', 'GTCAAT', 'CGATAA', 'CGCGTT', 'ATCGTA', 'TCGGTT', 
        'ATCAAC', 'ATTGG', 'TCGA', 'GCAATC', 'CAATCT', 'GCGTAC', 'TTCGAC', 'GGTTG', 'TCCAAT', 
        'CGTAGT', 'TTGCG', 'CGGTT', 'CGATTA', 'ACGGTT', 'ATCAAT', 'TTGCGC', 'CAATC', 'CGAT', 
        'GCGTTA', 'CCGTTA', 'TTGAC', 'CGTCGA', 'ATAGCG', 'GTTGAG', 'TATCCG', 'GGTAGT', 'CGTTGC', 
        'TCGGTA', 'TGGTT', 'AGGTTG', 'AGGAA', 'TCGAGT', 'TCAAT', 'ATAGGG', 'GTACGC', 'ACGCAA', 
        'GGTACG', 'TCCTG', 'CAGAG', 'TTGATG', 'GTCGAC', 'CGGTTG', 'ACATCG', 'CAGC', 'TTTTTT', 
        'GGTATG', 'TAGGGT', 'GGTTC', 'TGGTTC', 'CGCGTA', 'AACC', 'CTCGAT', 'AACGGT', 'ATCAA', 
        'TCCAAC', 'AAAATG', 'AAATG', 'GTTGT', 'GTCATA', 'TCAATT', 'ACAATC', 'AATAAA', 'AATTGG', 
        'ATCATA', 'GGCGTA', 'AAATAA', 'TCAAC', 'CTAACG', 'ACGATA', 'TCAACC', 'ACCGGT', 'CAGA', 
        'GCATAC', 'CTGTA', 'CGGTA', 'GTTGC', 'CTGT', 'ATTGGT', 'GGTCAA', 'CGTA', 'GTCAA', 'TCGCAA', 
        'AGCTG', 'ATGGTA', 'CGCAA', 'GTCAAA', 'GATTGG', 'CTGGA', 'TTCGCA', 'ATCCAA', 'AACCGA', 
        'CCGCAA', 'GTCGA', 'TAACAC', 'TTTTTA', 'ATAACG', 'TATGGT', 'TTGGCG', 'TGGT', 'TCCAT', 
        'CAATT', 'GCGTAA', 'TCGT', 'CCGTAA', 'GGGTTA', 'CAATTA', 'AGCCT', 'TAGCGA', 'TACCAC', 
        'CGCAAA', 'ATATCG', 'CTGCA', 'CGTACC', 'ATCGGT', 'TCGATA', 'TCGTTG', 'TTGGT', 'CGACCA', 
        'GAAGA', 'GT', 'CTGAG', 'ATGCGA', 'CAG', 'GGTAC', 'GGTTGT', 'CCATAC', 'GTTGCG', 'GATAGG', 
        'GAT', 'CAA', 'CATACC', 'AACCGT', 'TTGCGA', 'CGTAT', 'CGTAAT', 'CGATGT', 'TTCCT', 'AC', 
        'CGATCG', 'CGCTAA', 'CACAAC', 'TACC', 'TTGAG', 'CCAATC', 'TATGCG', 'TATCG', 'AGCAG', 'GGTAG', 
        'TCGTAG', 'AACCCG', 'AGAG', 'GAATCA', 'GAAGTT', 'GAAGAT', 'TCTTTA', 'CGAAGA', 'TCGAT', 'CAGT', 
        'CTTGA', 'TACG', 'CGTATG', 'CAAACA', 'TTCG', 'AGGGTT', 'TCGACC', 'CGTT', 'CTGTGA', 'TCAGT', 
        'CAGCT', 'GTGTCT', 'TGTAAA', 'ATGCCT', 'TAAACC', 'ATACCG', 'AACCG', 'CAACAA', 'CATTGG', 
        'GTACTC', 'TGTGAA', 'ATACCC', 'AACACC', 'TGCAGT', 'ATGTAA', 'AGGA', 'AAGCAC', 'GTAGGT', 
        'GTAGCT', 'CGTAGA', 'ACCCAA', 'CCAATA', 'TATTTT', 'CTTG', 'TTTTT', 'GCAATG', 'GTCGTC', 
        'GTCTAA', 'ATGCTG', 'CGTATC', 'TAGTTA', 'CAATCC', 'TTGGTC', 'TCGCA', 'GTCCAA', 'TAGGTC', 
        'CGAC', 'TGATC', 'CATAAC', 'TGATTA', 'CAATAG', 'TCTCGA', 'CTACAG', 'CTTTGG', 'TACGTC', 
        'CTCAGT', 'TTGG', 'TATTTG', 'AAACTG', 'TTCGCC', 'TGACAC', 'ACTCGT', 'CACAAA', 'TGACGA', 
        'CTTGAT', 'TCGACT', 'TGATCG', 'TAACG', 'ATATTT', 'TAGAGG', 'CCGATC', 'TCAACG', 'GTCGAT', 
        'GCGATA', 'ATGCCG', 'ACAAC', 'ACACCG', 'TTACCG', 'CGTAC', 'GTATTT', 'TTGCGT', 'CTCAG', 
        'CTTGCG', 'TTTCGA', 'TCGTA', 'TCCTGA', 'TACGCC', 'GAAG', 'GCTATC', 'CTAGTG', 'CCCTAT', 
        'ACCAGA', 'GTACTG', 'CATTTA', 'GTTAGA', 'ATAATC', 'AGGCAT', 'GATGTT', 'TAGATT', 'CAACGC', 
        'CGATTG', 'ACATTT', 'AAATGT', 'CCGAT', 'GTTATA', 'TGTTG', 'TTCAAT', 'GTCGTT', 'ACCGAT', 
        'CGATAC', 'TCGATG', 'CCACAC', 'CCAT', 'GGGTGT', 'CTATC', 'GTTGTG', 'CTTTCG', 'ATAGAT', 
        'TATGGC', 'AGCTGG', 'CTCT', 'CACAGA', 'TGGTTG', 'CTAG', 'ACGGGT', 'CATTTT', 'TTTTAG', 
        'CATAAT', 'AACCCA', 'CATAG', 'ACGGGA', 'GGTGTT', 'CCGTCC', 'AAGACC', 'ATTGCG', 'CAGTTT', 
        'TGAAGA', 'ATCG', 'AATTTG', 'TCAAAA', 'CCAAC', 'ATCA', 'TGCAG', 'CAAATT', 'ACGTTA', 'CGACTA', 
        'ACCCCT', 'CCCACT', 'CCGTAT', 'CAACGG', 'TCCATC', 'ACTAGG', 'AAGCAG', 'TTTGTA', 'GGGTCA', 
        'CGGTGT', 'GCAGTT', 'ACAATT', 'ACAACC', 'ACGTTG', 'AAATAC', 'TTCAGT', 'AGTTGA', 'GACATA', 
        'CTGACT', 'CTGTTT', 'CAAGGG', 'ATTTTA', 'CAAAC', 'TAGG', 'CTGAA', 'GCGATC', 'CAACCA', 
        'ATTCGC', 'CAATTC', 'CGTTAG', 'CACTAG', 'AGCAGT', 'CTTCTT', 'CAACTG', 'GGTGAG', 'TTCAG', 
        'AAATA', 'CGTTGT', 'TATCGC', 'AGCCA', 'GGTGAT', 'GGATAA', 'GCTGTA', 'GAAGTA', 'TTGAT', 
        'ACCGAC', 'TAGTCG', 'CTGTG', 'ATCTA', 'ACACCA', 'ATGGAT', 'CCTC', 'TGAAG', 'CGCACT', 'TAACCC', 
        'ACGTCA', 'TGATAG', 'TCGAA', 'ATACCA', 'AGGGTA', 'GATCGT', 'ATCCAG', 'TCAGC', 'GCAGAT', 
        'TACCTG', 'ACCCGT', 'CCATA', 'AATTGA', 'AGGTAC', 'GGT', 'CTGCCT', 'ACTAGT', 'TTGTTC', 'TTACTT', 
        'TTTTA', 'CAGAC', 'GCGTAG', 'GAGCAT', 'ATC', 'ATGG', 'AAGCCT', 'CACTCG', 'TCAGTG', 'CTGGAG', 
        'CTTCCT', 'CGTCAT', 'CCGTTG', 'TAGTTG', 'CGTCCA', 'GCCCAG', 'ATGGT', 'TACAC', 'GATAGT', 
        'ACAACA', 'CTATAG', 'AATGGT', 'AGAAA', 'ATGACG', 'GATAAC', 'CAGCTT', 'CATGAT', 'TTCGTT', 
        'GTGTAC', 'TTGAAC', 'CACAAG', 'AATTG', 'GTCA', 'TGCCT', 'CTCGAC', 'CTATCT', 'TGACGG', 
        'CCATAT', 'ACCATT', 'AAAGAG', 'ATTAGA', 'GCGTAT', 'CGTTG', 'TACGT', 'ACGAT', 'TCCATG', 
        'CCTG', 'GTCAAC', 'TTGTGA', 'ACTAG', 'GCGACA', 'TGAAGC', 'TACAAC', 'ACGGTA', 'TAGCGG', 
        'ATTGAT', 'ATCACG', 'ATTCGG', 'TATTTC', 'TAAAAT', 'GTATCG', 'CAACCG', 'CCCCAA', 'CGTAAC',
        'CTAGGG', 'ATCAAA', 'ATTGGA', 'TCGTC', 'GCAACT', 'CACTA', 'CCATAG', 'CACAA', 'ATAGGT', 
        'ACGTAG', 'CATGCG', 'ATGATC', 'CCGTCA', 'CGATT', 'TTTGAC', 'CGTTA', 'TCTGTA', 'TAGATC', 
        'CATAGC', 'TCCAGA', 'ACACTC', 'CGATCA', 'GGATGT', 'TTACGC', 'AACTGC', 'ATCCAT', 'CCACTC', 
        'GTCCAT', 'ACCACT', 'GCGCGG', 'GTCAAG', 'AAGTGT', 'ATGATA', 'AGCT', 'CTAGAG', 'GCAGA', 
        'GTCATG', 'CTGTAG', 'TCATGC', 'CAGAA', 'ACACGG', 'CGGTAT', 'TTTTAA', 'TCAAAG', 'TTACAC', 
        'TCCGCT', 'CCCCCC', 'GCACAA', 'TTCTGT', 'TATGTA', 'GGTAAC', 'TAGCG', 'ATACC', 'GGTATC', 
        'ACAA', 'TCTGT', 'ACTA', 'TCCGTA', 'CTATCA', 'CGCATA', 'TCTCAG', 'CATGGA', 'ATCT', 'TGCGAC', 
        'ACAC', 'GACCAT', 'CAGCAT', 'ACG', 'CTAGTA', 'TTAGCG', 'TAACGA', 'ACTGAG', 'GAAGT', 'CTTGAC', 
        'CGTAGG', 'TCGCTC', 'CTGAAG', 'TTGACA', 'CGGCAA', 'CTCAAG', 'ACGTA', 'CAAGTG', 'TCAGA', 'GAGCAA', 
        'CGAAAG', 'ACTTTT', 'TACCG', 'GTTGTT', 'GCCATA', 'GCGTA', 'ACGA', 'TCGACG', 'ATACG', 'GTAC', 
        'TTGCCG', 'GGCGGG', 'CTAGT', 'GAACCA', 'TTTCTG', 'TCTTGA', 'TAAAA', 'TTGAGG', 'TAACGC', 'TATAGG',
        'GTCGTA', 'GCATTT', 'TACTG', 'TATCGA', 'CGTAA', 'AGGCTT', 'CGTTAT', 'TATC', 'TTGATT', 'TGCAGA', 
        'TAGGCG', 'GCTTGA', 'ATCTAT', 'GGTTAG', 'TACAAT']

c = [f for f in l if len(f) < 6]
b = [f for f in l if len(f) == 6]
b1 = [f for f in b if f[0] == 'A' or f[0] == 'T']
b2 = [f for f in b if f[0] == 'G' or f[0] == 'C']

df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam'] + c], 
                 pd.read_csv('drive/My Drive/ppnnw6.csv')[b]], axis = 1)

df1 = df1.loc[df1['die'] == 'no']
df1['Gen'] = 1

df2 = pd.concat([pd.read_csv('drive/My Drive/h1w5.csv')[['die'] + c], 
                 pd.read_csv('drive/My Drive/h1w6p1.csv')[b1],
                 pd.read_csv('drive/My Drive/h1w6p2.csv')[b2]], axis = 1)
df2 = df2.loc[df2['die'] == 'no']
df2['Gen'] = 0

data = pd.concat([df1, df2], axis = 0).reset_index(drop = True)

# %%
temp = []
for i in range(5):
  #Splitting features and labels
  X = data.iloc[:, 3:].values.astype(float)
  y = data.iloc[:, 0].values.astype(float)

  # Splitting the dataset into the Training set and Test set
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

  # Feature Scaling
  sc = StandardScaler()
  X_train = sc.fit_transform(X_train)
  X_test = sc.transform(X_test)

  ### Training the decision tree model on the Training set
  classifier = LogisticRegression(max_iter = 2000)
  classifier.fit(X_train, y_train)

  # Predicting the Test set results
  y_pred = classifier.predict(X_test)

  # Making the Confusion Matrix
  cm = confusion_matrix(y_test, y_pred)

  #evaluation
  cv_bin = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1')
  cv_mac = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1_macro')
  f1bin = f1_score(y_test, y_pred, average='binary')
  f1mac = f1_score(y_test, y_pred, average='macro')

  #AUC
  acc = metrics.accuracy_score(y_test, y_pred)
  y_pred_proba = classifier.predict_proba(X_test)[::,1]
  fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
  auc = metrics.roc_auc_score(y_test, y_pred_proba)
  plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
  plt.legend(loc=4)
  plt.show()

  temp.append((cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
  print('correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** cv_bin mean: %f ** cv_bin std: %f ** cv_mac mean: %f ** cv_mac std: %f ** f1bin: %f ** f1mac: %f' 
        % (cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
# Out:
# correct/TP: 1020 ** FP: 0 **  TN: 3878 ** FN: 0 ** cv_bin mean: 0.999194 ** cv_bin std: 0.001485 ** cv_mac mean: 0.999489 ** cv_mac std: 0.000942 ** f1bin: 1.000000 ** f1mac: 1.000000
# correct/TP: 1005 ** FP: 1 **  TN: 3892 ** FN: 0 ** cv_bin mean: 0.999198 ** cv_bin std: 0.001076 ** cv_mac mean: 0.999491 ** cv_mac std: 0.000683 ** f1bin: 0.999503 ** f1mac: 0.999687
# correct/TP: 1039 ** FP: 2 **  TN: 3857 ** FN: 0 ** cv_bin mean: 0.999514 ** cv_bin std: 0.001037 ** cv_mac mean: 0.999692 ** cv_mac std: 0.000656 ** f1bin: 0.999038 ** f1mac: 0.999390
# correct/TP: 1047 ** FP: 4 **  TN: 3847 ** FN: 0 ** cv_bin mean: 0.999349 ** cv_bin std: 0.001080 ** cv_mac mean: 0.999588 ** cv_mac std: 0.000683 ** f1bin: 0.998093 ** f1mac: 0.998787
# correct/TP: 1018 ** FP: 1 **  TN: 3879 ** FN: 0 ** cv_bin mean: 0.999194 ** cv_bin std: 0.001080 ** cv_mac mean: 0.999489 ** cv_mac std: 0.000685 ** f1bin: 0.999509 ** f1mac: 0.999690

# %% [markdown]
# LOFO CV

# %%
temp = []

df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam'] + c], 
                 pd.read_csv('drive/My Drive/ppnnw6.csv')[b]], axis = 1)
df1['Gen'] = 1

df2test = df2.sample(frac = 0.3)
df2train = df2[~df2.index.isin(df2test.index)]

for fam in set(df1['Fam'].to_list()):
    df1test = df1.loc[df1['Fam'] == fam]
    df1train = df1.loc[~(df1['Fam'] == fam)]
    df1train = df1train.loc[df1train['die'] == 'no']
    
    X_train = pd.concat([df1train.iloc[:,3:], df2train.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_train = pd.concat([df1train.iloc[:,0], df2train.iloc[:,-1]], axis = 0).reset_index(drop = True)

    X_test = pd.concat([df1test.iloc[:,3:], df2test.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_test = pd.concat([df1test.iloc[:,0], df2test.iloc[:,-1]], axis = 0).reset_index(drop = True)
    
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    # Fitting Random Forest Classification to the Training set
    classifier = LogisticRegression(max_iter = 2000)
    classifier.fit(X_train, y_train)
    
    # Predicting the Test set results
    y_pred = classifier.predict(X_test)
    
    # Making the Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    #evaluation
    f1bin = f1_score(y_test, y_pred, average='binary')
    f1mac = f1_score(y_test, y_pred, average='macro')
    
    temp.append((fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))

    print('Fam: %s ** total: %d ** correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** f1bin: %f ** f1mac: %f' 
          % (fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))
  
lrlofocv_194f = pd.DataFrame(temp, columns = ['Fam', 'Total', 'Correct/TP', 'FP', 'TN', 'FN', 'f1bin', 'f1mac'])
# Out:
# Fam: hepeviridae ** total: 32 ** correct/TP: 32 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: paramyxoviridae ** total: 214 ** correct/TP: 214 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: peribunyaviridae ** total: 4 ** correct/TP: 4 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: chuviridae ** total: 4 ** correct/TP: 4 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: tobaniviridae ** total: 16 ** correct/TP: 16 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: bornaviridae ** total: 24 ** correct/TP: 24 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: gammaflexiviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: nyamiviridae ** total: 6 ** correct/TP: 6 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: sunviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: coronaviridae ** total: 690 ** correct/TP: 690 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: tymoviridae ** total: 82 ** correct/TP: 82 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: nodaviridae ** total: 20 ** correct/TP: 20 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: flaviviridae ** total: 390 ** correct/TP: 387 ** FP: 0 **  TN: 4643 ** FN: 3 ** f1bin: 0.996139 ** f1mac: 0.997908
# Fam: arteriviridae ** total: 48 ** correct/TP: 48 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: leviviridae ** total: 24 ** correct/TP: 24 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: bromoviridae ** total: 30 ** correct/TP: 30 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: marnaviridae ** total: 20 ** correct/TP: 20 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: artoviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: mononiviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: deltaflexiviridae ** total: 4 ** correct/TP: 4 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: kitaviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: endornaviridae ** total: 60 ** correct/TP: 60 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: mymonaviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: tombusviridae ** total: 136 ** correct/TP: 136 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: fimoviridae ** total: 8 ** correct/TP: 8 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: filoviridae ** total: 32 ** correct/TP: 32 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: carmotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: closteroviridae ** total: 90 ** correct/TP: 90 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: virgaviridae ** total: 86 ** correct/TP: 86 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: pneumoviridae ** total: 30 ** correct/TP: 30 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: roniviridae ** total: 4 ** correct/TP: 4 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: secoviridae ** total: 36 ** correct/TP: 36 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: barnaviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: alvernaviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: hantaviridae ** total: 12 ** correct/TP: 12 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: mesoniviridae ** total: 26 ** correct/TP: 26 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: astroviridae ** total: 132 ** correct/TP: 132 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: picornaviridae ** total: 864 ** correct/TP: 863 ** FP: 0 **  TN: 4643 ** FN: 1 ** f1bin: 0.999421 ** f1mac: 0.999657
# Fam: potyviridae ** total: 362 ** correct/TP: 362 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: betaflexiviridae ** total: 222 ** correct/TP: 222 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: togaviridae ** total: 84 ** correct/TP: 84 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: solemoviridae ** total: 38 ** correct/TP: 38 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: luteoviridae ** total: 106 ** correct/TP: 106 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: polycipiviridae ** total: 10 ** correct/TP: 10 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: aspiviridae ** total: 4 ** correct/TP: 4 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: alphaflexiviridae ** total: 110 ** correct/TP: 110 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: hypoviridae ** total: 24 ** correct/TP: 24 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: alphatetraviridae ** total: 8 ** correct/TP: 8 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: dicistroviridae ** total: 40 ** correct/TP: 40 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: matonaviridae ** total: 4 ** correct/TP: 4 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: caliciviridae ** total: 1762 ** correct/TP: 1762 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: narnaviridae ** total: 72 ** correct/TP: 72 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: benyviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: rhabdoviridae ** total: 220 ** correct/TP: 220 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: permutotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: iflaviridae ** total: 76 ** correct/TP: 76 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: nairoviridae ** total: 2 ** correct/TP: 2 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000

# %%
lrlofocv_194f
# Out:
#                     Fam  Total  Correct/TP  FP    TN  FN     f1bin     f1mac
# 0           hepeviridae     32          32   0  4643   0  1.000000  1.000000
# 1       paramyxoviridae    214         214   0  4643   0  1.000000  1.000000
# 2      peribunyaviridae      4           4   0  4643   0  1.000000  1.000000
# 3            chuviridae      4           4   0  4643   0  1.000000  1.000000
# 4         tobaniviridae     16          16   0  4643   0  1.000000  1.000000
# 5          bornaviridae     24          24   0  4643   0  1.000000  1.000000
# 6     gammaflexiviridae      2           2   0  4643   0  1.000000  1.000000
# 7          nyamiviridae      6           6   0  4643   0  1.000000  1.000000
# 8            sunviridae      2           2   0  4643   0  1.000000  1.000000
# 9         coronaviridae    690         690   0  4643   0  1.000000  1.000000
# 10          tymoviridae     82          82   0  4643   0  1.000000  1.000000
# 11          nodaviridae     20          20   0  4643   0  1.000000  1.000000
# 12         flaviviridae    390         387   0  4643   3  0.996139  0.997908
# 13        arteriviridae     48          48   0  4643   0  1.000000  1.000000
# 14          leviviridae     24          24   0  4643   0  1.000000  1.000000
# 15         bromoviridae     30          30   0  4643   0  1.000000  1.000000
# 16         marnaviridae     20          20   0  4643   0  1.000000  1.000000
# 17          artoviridae      2           2   0  4643   0  1.000000  1.000000
# 18        mononiviridae      2           2   0  4643   0  1.000000  1.000000
# 19    deltaflexiviridae      4           4   0  4643   0  1.000000  1.000000
# 20          kitaviridae      2           2   0  4643   0  1.000000  1.000000
# 21       endornaviridae     60          60   0  4643   0  1.000000  1.000000
# 22        mymonaviridae      2           2   0  4643   0  1.000000  1.000000
# 23        tombusviridae    136         136   0  4643   0  1.000000  1.000000
# 24          fimoviridae      8           8   0  4643   0  1.000000  1.000000
# 25          filoviridae     32          32   0  4643   0  1.000000  1.000000
# 26    carmotetraviridae      2           2   0  4643   0  1.000000  1.000000
# 27      closteroviridae     90          90   0  4643   0  1.000000  1.000000
# 28         virgaviridae     86          86   0  4643   0  1.000000  1.000000
# 29        pneumoviridae     30          30   0  4643   0  1.000000  1.000000
# 30          roniviridae      4           4   0  4643   0  1.000000  1.000000
# 31          secoviridae     36          36   0  4643   0  1.000000  1.000000
# 32         barnaviridae      2           2   0  4643   0  1.000000  1.000000
# 33       alvernaviridae      2           2   0  4643   0  1.000000  1.000000
# 34         hantaviridae     12          12   0  4643   0  1.000000  1.000000
# 35        mesoniviridae     26          26   0  4643   0  1.000000  1.000000
# 36         astroviridae    132         132   0  4643   0  1.000000  1.000000
# 37       picornaviridae    864         863   0  4643   1  0.999421  0.999657
# 38          potyviridae    362         362   0  4643   0  1.000000  1.000000
# 39     betaflexiviridae    222         222   0  4643   0  1.000000  1.000000
# 40          togaviridae     84          84   0  4643   0  1.000000  1.000000
# 41        solemoviridae     38          38   0  4643   0  1.000000  1.000000
# 42         luteoviridae    106         106   0  4643   0  1.000000  1.000000
# 43      polycipiviridae     10          10   0  4643   0  1.000000  1.000000
# 44          aspiviridae      4           4   0  4643   0  1.000000  1.000000
# 45    alphaflexiviridae    110         110   0  4643   0  1.000000  1.000000
# 46          hypoviridae     24          24   0  4643   0  1.000000  1.000000
# 47    alphatetraviridae      8           8   0  4643   0  1.000000  1.000000
# 48      dicistroviridae     40          40   0  4643   0  1.000000  1.000000
# 49        matonaviridae      4           4   0  4643   0  1.000000  1.000000
# 50        caliciviridae   1762        1762   0  4643   0  1.000000  1.000000
# 51         narnaviridae     72          72   0  4643   0  1.000000  1.000000
# 52          benyviridae      2           2   0  4643   0  1.000000  1.000000
# 53        rhabdoviridae    220         220   0  4643   0  1.000000  1.000000
# 54  permutotetraviridae      2           2   0  4643   0  1.000000  1.000000
# 55          iflaviridae     76          76   0  4643   0  1.000000  1.000000
# 56         nairoviridae      2           2   0  4643   0  1.000000  1.000000

# %% [markdown]
# # 68 Features

# %%
l =    ['TCAATC', 'CCAATT', 'GTTGAC', 'TGAT', 'GGTT', 'GGTTGA', 'GTTGA',
       'TAGCGT', 'CGGTTA', 'TTGACG', 'CGATA', 'CGTCAA', 'CAATCG', 'CGTTGA',
       'GTCGAA', 'GTTG', 'CGGTAA', 'CATACG', 'AAAAAA', 'ACCAAT', 'TCAA',
       'TTGTCG', 'CGATAG', 'AAAAA', 'CAAC', 'ATACGC', 'CAATTG', 'CCAAT',
       'CGCAAT', 'GGTA', 'CAAT', 'TGTCGA', 'CGAT', 'CAATCT', 'GCGTAC', 'GGTTG',
       'TTGA', 'GTTGGT', 'TCCAAT', 'TTGCG', 'ACGGTT', 'CGATTA', 'ATCAAT',
       'GCAATC', 'ATCAAC', 'GTTGAT', 'GTCAAT', 'CGTCGA', 'ATTGG', 'CGTAGT',
       'ATAGCG', 'CCGATA', 'CAATC', 'CATCAA', 'TTCGAC', 'TTGAC', 'TTGCGC',
       'GCGTTA', 'CCGTTA', 'ATACGG', 'CGCGTT', 'CGATC', 'CGATAA', 'ATCGTA',
       'TCGA', 'TCGGTT', 'GATC', 'CGGTT']

c = [f for f in l if len(f) < 6]
b = [f for f in l if len(f) == 6]
b1 = [f for f in b if f[0] == 'A' or f[0] == 'T']
b2 = [f for f in b if f[0] == 'G' or f[0] == 'C']

df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam'] + c], 
                 pd.read_csv('drive/My Drive/ppnnw6.csv')[b]], axis = 1)

df1 = df1.loc[df1['die'] == 'no']
df1['Gen'] = 1

df2 = pd.concat([pd.read_csv('drive/My Drive/h1w5.csv')[['die'] + c], 
                 pd.read_csv('drive/My Drive/h1w6p1.csv')[b1],
                 pd.read_csv('drive/My Drive/h1w6p2.csv')[b2]], axis = 1)
df2 = df2.loc[df2['die'] == 'no']
df2['Gen'] = 0

data = pd.concat([df1, df2], axis = 0).reset_index(drop = True)

# %%
temp = []
for i in range(5):
  #Splitting features and labels
  X = data.iloc[:, 3:].values.astype(float)
  y = data.iloc[:, 0].values.astype(float)

  # Splitting the dataset into the Training set and Test set
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

  # Feature Scaling
  sc = StandardScaler()
  X_train = sc.fit_transform(X_train)
  X_test = sc.transform(X_test)

  ### Training the decision tree model on the Training set
  classifier = LogisticRegression(max_iter = 2000)
  classifier.fit(X_train, y_train)

  # Predicting the Test set results
  y_pred = classifier.predict(X_test)

  # Making the Confusion Matrix
  cm = confusion_matrix(y_test, y_pred)

  #evaluation
  cv_bin = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1')
  cv_mac = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1_macro')
  f1bin = f1_score(y_test, y_pred, average='binary')
  f1mac = f1_score(y_test, y_pred, average='macro')

  #AUC
  acc = metrics.accuracy_score(y_test, y_pred)
  y_pred_proba = classifier.predict_proba(X_test)[::,1]
  fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
  auc = metrics.roc_auc_score(y_test, y_pred_proba)
  plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
  plt.legend(loc=4)
  plt.show()

  temp.append((cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
  print('correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** cv_bin mean: %f ** cv_bin std: %f ** cv_mac mean: %f ** cv_mac std: %f ** f1bin: %f ** f1mac: %f' 
        % (cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
# Out:
# correct/TP: 1061 ** FP: 11 **  TN: 3808 ** FN: 18 ** cv_bin mean: 0.984864 ** cv_bin std: 0.004912 ** cv_mac mean: 0.990458 ** cv_mac std: 0.003099 ** f1bin: 0.986518 ** f1mac: 0.991362
# correct/TP: 1010 ** FP: 16 **  TN: 3860 ** FN: 12 ** cv_bin mean: 0.984985 ** cv_bin std: 0.004719 ** cv_mac mean: 0.990487 ** cv_mac std: 0.002993 ** f1bin: 0.986328 ** f1mac: 0.991357
# correct/TP: 1003 ** FP: 26 **  TN: 3857 ** FN: 12 ** cv_bin mean: 0.987763 ** cv_bin std: 0.004745 ** cv_mac mean: 0.992242 ** cv_mac std: 0.003016 ** f1bin: 0.981409 ** f1mac: 0.988254
# correct/TP: 1025 ** FP: 10 **  TN: 3851 ** FN: 12 ** cv_bin mean: 0.983759 ** cv_bin std: 0.005604 ** cv_mac mean: 0.989727 ** cv_mac std: 0.003549 ** f1bin: 0.989382 ** f1mac: 0.993267
# correct/TP: 1005 ** FP: 14 **  TN: 3859 ** FN: 20 ** cv_bin mean: 0.985469 ** cv_bin std: 0.005789 ** cv_mac mean: 0.990794 ** cv_mac std: 0.003673 ** f1bin: 0.983366 ** f1mac: 0.989490

# %%
temp = []

df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam'] + c], 
                 pd.read_csv('drive/My Drive/ppnnw6.csv')[b]], axis = 1)
df1['Gen'] = 1

df2test = df2.sample(frac = 0.3)
df2train = df2[~df2.index.isin(df2test.index)]

for fam in set(df1['Fam'].to_list()):
    df1test = df1.loc[df1['Fam'] == fam]
    df1train = df1.loc[~(df1['Fam'] == fam)]
    df1train = df1train.loc[df1train['die'] == 'no']
    
    X_train = pd.concat([df1train.iloc[:,3:], df2train.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_train = pd.concat([df1train.iloc[:,0], df2train.iloc[:,-1]], axis = 0).reset_index(drop = True)

    X_test = pd.concat([df1test.iloc[:,3:], df2test.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_test = pd.concat([df1test.iloc[:,0], df2test.iloc[:,-1]], axis = 0).reset_index(drop = True)
    
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    # Fitting Random Forest Classification to the Training set
    classifier = LogisticRegression(max_iter = 2000)
    classifier.fit(X_train, y_train)
    
    # Predicting the Test set results
    y_pred = classifier.predict(X_test)
    
    # Making the Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    #evaluation
    f1bin = f1_score(y_test, y_pred, average='binary')
    f1mac = f1_score(y_test, y_pred, average='macro')
    
    temp.append((fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))

    print('Fam: %s ** total: %d ** correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** f1bin: %f ** f1mac: %f' 
          % (fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))
  
lrlofocv_68f = pd.DataFrame(temp, columns = ['Fam', 'Total', 'Correct/TP', 'FP', 'TN', 'FN', 'f1bin', 'f1mac'])
# Out:
# Fam: hepeviridae ** total: 32 ** correct/TP: 32 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.790123 ** f1mac: 0.894145
# Fam: paramyxoviridae ** total: 214 ** correct/TP: 214 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.961798 ** f1mac: 0.979982
# Fam: peribunyaviridae ** total: 4 ** correct/TP: 3 ** FP: 17 **  TN: 4626 ** FN: 1 ** f1bin: 0.250000 ** f1mac: 0.624029
# Fam: chuviridae ** total: 4 ** correct/TP: 4 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.320000 ** f1mac: 0.659083
# Fam: tobaniviridae ** total: 16 ** correct/TP: 16 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.653061 ** f1mac: 0.825614
# Fam: bornaviridae ** total: 24 ** correct/TP: 24 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.738462 ** f1mac: 0.868314
# Fam: gammaflexiviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: nyamiviridae ** total: 6 ** correct/TP: 3 ** FP: 16 **  TN: 4627 ** FN: 3 ** f1bin: 0.240000 ** f1mac: 0.618976
# Fam: sunviridae ** total: 2 ** correct/TP: 1 ** FP: 17 **  TN: 4626 ** FN: 1 ** f1bin: 0.100000 ** f1mac: 0.549029
# Fam: coronaviridae ** total: 690 ** correct/TP: 690 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.987831 ** f1mac: 0.992998
# Fam: tymoviridae ** total: 82 ** correct/TP: 72 ** FP: 14 **  TN: 4629 ** FN: 10 ** f1bin: 0.857143 ** f1mac: 0.927279
# Fam: nodaviridae ** total: 20 ** correct/TP: 20 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.701754 ** f1mac: 0.849960
# Fam: flaviviridae ** total: 390 ** correct/TP: 342 ** FP: 15 **  TN: 4628 ** FN: 48 ** f1bin: 0.915663 ** f1mac: 0.954451
# Fam: arteriviridae ** total: 48 ** correct/TP: 48 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.849558 ** f1mac: 0.923862
# Fam: leviviridae ** total: 24 ** correct/TP: 24 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.738462 ** f1mac: 0.868314
# Fam: bromoviridae ** total: 30 ** correct/TP: 30 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.779221 ** f1mac: 0.888693
# Fam: marnaviridae ** total: 20 ** correct/TP: 20 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.701754 ** f1mac: 0.849960
# Fam: artoviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: mononiviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: deltaflexiviridae ** total: 4 ** correct/TP: 4 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.320000 ** f1mac: 0.659083
# Fam: kitaviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: endornaviridae ** total: 60 ** correct/TP: 60 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.875912 ** f1mac: 0.937039
# Fam: mymonaviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: tombusviridae ** total: 136 ** correct/TP: 136 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.941176 ** f1mac: 0.969671
# Fam: fimoviridae ** total: 8 ** correct/TP: 6 ** FP: 18 **  TN: 4625 ** FN: 2 ** f1bin: 0.375000 ** f1mac: 0.686421
# Fam: filoviridae ** total: 32 ** correct/TP: 32 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.790123 ** f1mac: 0.894145
# Fam: carmotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: closteroviridae ** total: 90 ** correct/TP: 90 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.913706 ** f1mac: 0.955936
# Fam: virgaviridae ** total: 86 ** correct/TP: 86 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.910053 ** f1mac: 0.954109
# Fam: pneumoviridae ** total: 30 ** correct/TP: 29 ** FP: 17 **  TN: 4626 ** FN: 1 ** f1bin: 0.763158 ** f1mac: 0.880608
# Fam: roniviridae ** total: 4 ** correct/TP: 4 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.320000 ** f1mac: 0.659083
# Fam: secoviridae ** total: 36 ** correct/TP: 35 ** FP: 17 **  TN: 4626 ** FN: 1 ** f1bin: 0.795455 ** f1mac: 0.896756
# Fam: barnaviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: alvernaviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: hantaviridae ** total: 12 ** correct/TP: 11 ** FP: 17 **  TN: 4626 ** FN: 1 ** f1bin: 0.550000 ** f1mac: 0.774029
# Fam: mesoniviridae ** total: 26 ** correct/TP: 26 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.753623 ** f1mac: 0.875895
# Fam: astroviridae ** total: 132 ** correct/TP: 132 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.939502 ** f1mac: 0.968834
# Fam: picornaviridae ** total: 864 ** correct/TP: 849 ** FP: 21 **  TN: 4622 ** FN: 15 ** f1bin: 0.979239 ** f1mac: 0.987680
# Fam: potyviridae ** total: 362 ** correct/TP: 361 ** FP: 18 **  TN: 4625 ** FN: 1 ** f1bin: 0.974359 ** f1mac: 0.986155
# Fam: betaflexiviridae ** total: 222 ** correct/TP: 221 ** FP: 18 **  TN: 4625 ** FN: 1 ** f1bin: 0.958785 ** f1mac: 0.978368
# Fam: togaviridae ** total: 84 ** correct/TP: 84 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.908108 ** f1mac: 0.953137
# Fam: solemoviridae ** total: 38 ** correct/TP: 38 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.817204 ** f1mac: 0.907685
# Fam: luteoviridae ** total: 106 ** correct/TP: 106 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.925764 ** f1mac: 0.961965
# Fam: polycipiviridae ** total: 10 ** correct/TP: 10 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.540541 ** f1mac: 0.769353
# Fam: aspiviridae ** total: 4 ** correct/TP: 3 ** FP: 17 **  TN: 4626 ** FN: 1 ** f1bin: 0.250000 ** f1mac: 0.624029
# Fam: alphaflexiviridae ** total: 110 ** correct/TP: 109 ** FP: 17 **  TN: 4626 ** FN: 1 ** f1bin: 0.923729 ** f1mac: 0.960894
# Fam: hypoviridae ** total: 24 ** correct/TP: 24 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.738462 ** f1mac: 0.868314
# Fam: alphatetraviridae ** total: 8 ** correct/TP: 8 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.484848 ** f1mac: 0.741507
# Fam: dicistroviridae ** total: 40 ** correct/TP: 40 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.824742 ** f1mac: 0.911454
# Fam: matonaviridae ** total: 4 ** correct/TP: 4 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.320000 ** f1mac: 0.659083
# Fam: caliciviridae ** total: 1762 ** correct/TP: 1760 ** FP: 19 **  TN: 4624 ** FN: 2 ** f1bin: 0.994069 ** f1mac: 0.995902
# Fam: narnaviridae ** total: 72 ** correct/TP: 68 ** FP: 19 **  TN: 4624 ** FN: 4 ** f1bin: 0.855346 ** f1mac: 0.926433
# Fam: benyviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: rhabdoviridae ** total: 220 ** correct/TP: 219 ** FP: 17 **  TN: 4626 ** FN: 1 ** f1bin: 0.960526 ** f1mac: 0.979292
# Fam: permutotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321
# Fam: iflaviridae ** total: 76 ** correct/TP: 76 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.899408 ** f1mac: 0.948787
# Fam: nairoviridae ** total: 2 ** correct/TP: 2 ** FP: 17 **  TN: 4626 ** FN: 0 ** f1bin: 0.190476 ** f1mac: 0.594321

# %%
lrlofocv_68f
# Out:
#                     Fam  Total  Correct/TP  FP    TN  FN     f1bin     f1mac
# 0           hepeviridae     32          32  17  4626   0  0.790123  0.894145
# 1       paramyxoviridae    214         214  17  4626   0  0.961798  0.979982
# 2      peribunyaviridae      4           3  17  4626   1  0.250000  0.624029
# 3            chuviridae      4           4  17  4626   0  0.320000  0.659083
# 4         tobaniviridae     16          16  17  4626   0  0.653061  0.825614
# 5          bornaviridae     24          24  17  4626   0  0.738462  0.868314
# 6     gammaflexiviridae      2           2  17  4626   0  0.190476  0.594321
# 7          nyamiviridae      6           3  16  4627   3  0.240000  0.618976
# 8            sunviridae      2           1  17  4626   1  0.100000  0.549029
# 9         coronaviridae    690         690  17  4626   0  0.987831  0.992998
# 10          tymoviridae     82          72  14  4629  10  0.857143  0.927279
# 11          nodaviridae     20          20  17  4626   0  0.701754  0.849960
# 12         flaviviridae    390         342  15  4628  48  0.915663  0.954451
# 13        arteriviridae     48          48  17  4626   0  0.849558  0.923862
# 14          leviviridae     24          24  17  4626   0  0.738462  0.868314
# 15         bromoviridae     30          30  17  4626   0  0.779221  0.888693
# 16         marnaviridae     20          20  17  4626   0  0.701754  0.849960
# 17          artoviridae      2           2  17  4626   0  0.190476  0.594321
# 18        mononiviridae      2           2  17  4626   0  0.190476  0.594321
# 19    deltaflexiviridae      4           4  17  4626   0  0.320000  0.659083
# 20          kitaviridae      2           2  17  4626   0  0.190476  0.594321
# 21       endornaviridae     60          60  17  4626   0  0.875912  0.937039
# 22        mymonaviridae      2           2  17  4626   0  0.190476  0.594321
# 23        tombusviridae    136         136  17  4626   0  0.941176  0.969671
# 24          fimoviridae      8           6  18  4625   2  0.375000  0.686421
# 25          filoviridae     32          32  17  4626   0  0.790123  0.894145
# 26    carmotetraviridae      2           2  17  4626   0  0.190476  0.594321
# 27      closteroviridae     90          90  17  4626   0  0.913706  0.955936
# 28         virgaviridae     86          86  17  4626   0  0.910053  0.954109
# 29        pneumoviridae     30          29  17  4626   1  0.763158  0.880608
# 30          roniviridae      4           4  17  4626   0  0.320000  0.659083
# 31          secoviridae     36          35  17  4626   1  0.795455  0.896756
# 32         barnaviridae      2           2  17  4626   0  0.190476  0.594321
# 33       alvernaviridae      2           2  17  4626   0  0.190476  0.594321
# 34         hantaviridae     12          11  17  4626   1  0.550000  0.774029
# 35        mesoniviridae     26          26  17  4626   0  0.753623  0.875895
# 36         astroviridae    132         132  17  4626   0  0.939502  0.968834
# 37       picornaviridae    864         849  21  4622  15  0.979239  0.987680
# 38          potyviridae    362         361  18  4625   1  0.974359  0.986155
# 39     betaflexiviridae    222         221  18  4625   1  0.958785  0.978368
# 40          togaviridae     84          84  17  4626   0  0.908108  0.953137
# 41        solemoviridae     38          38  17  4626   0  0.817204  0.907685
# 42         luteoviridae    106         106  17  4626   0  0.925764  0.961965
# 43      polycipiviridae     10          10  17  4626   0  0.540541  0.769353
# 44          aspiviridae      4           3  17  4626   1  0.250000  0.624029
# 45    alphaflexiviridae    110         109  17  4626   1  0.923729  0.960894
# 46          hypoviridae     24          24  17  4626   0  0.738462  0.868314
# 47    alphatetraviridae      8           8  17  4626   0  0.484848  0.741507
# 48      dicistroviridae     40          40  17  4626   0  0.824742  0.911454
# 49        matonaviridae      4           4  17  4626   0  0.320000  0.659083
# 50        caliciviridae   1762        1760  19  4624   2  0.994069  0.995902
# 51         narnaviridae     72          68  19  4624   4  0.855346  0.926433
# 52          benyviridae      2           2  17  4626   0  0.190476  0.594321
# 53        rhabdoviridae    220         219  17  4626   1  0.960526  0.979292
# 54  permutotetraviridae      2           2  17  4626   0  0.190476  0.594321
# 55          iflaviridae     76          76  17  4626   0  0.899408  0.948787
# 56         nairoviridae      2           2  17  4626   0  0.190476  0.594321
