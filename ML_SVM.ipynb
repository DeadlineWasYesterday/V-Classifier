# %% [markdown]
# # Load libraries

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # All features

# %%
df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam']],
                 pd.read_csv('drive/My Drive/ppnnw5.csv').iloc[:,10:],
                 pd.read_csv('drive/My Drive/ppnnw6.csv').iloc[:,10:]], axis = 1)

df1 = df1.loc[df1['die'] == 'no']
df1['Gen'] = 1
df2 = pd.concat([pd.read_csv('drive/My Drive/h1w5.csv')[['die']],
                 pd.read_csv('drive/My Drive/h1w5.csv').iloc[:, 5:], 
                 pd.read_csv('drive/My Drive/h1w6p1.csv').iloc[:,5:],
                 pd.read_csv('drive/My Drive/h1w6p2.csv').iloc[:,5:]], axis = 1)
df2 = df2.loc[df2['die'] == 'no']
df2['Gen'] = 0

data = pd.concat([df1, df2], axis = 0).reset_index(drop = True)

# %% [markdown]
# Model performance with all features

# %%
temp = []
for i in range(5):
  #Splitting features and labels
  X = data.iloc[:, 3:].values.astype(float)
  y = data.iloc[:, 0].values.astype(float)

  # Splitting the dataset into the Training set and Test set
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

  # Feature Scaling
  sc = StandardScaler()
  X_train = sc.fit_transform(X_train)
  X_test = sc.transform(X_test)

  ### Training the decision tree model on the Training set
  classifier = SVC(kernel = 'linear')
  classifier.fit(X_train, y_train)

  # Predicting the Test set results
  y_pred = classifier.predict(X_test)

  # Making the Confusion Matrix
  cm = confusion_matrix(y_test, y_pred)

  #evaluation
  cv_bin = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1')
  cv_mac = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1_macro')
  f1bin = f1_score(y_test, y_pred, average='binary')
  f1mac = f1_score(y_test, y_pred, average='macro')

  temp.append((cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
  print('correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** cv_bin mean: %f ** cv_bin std: %f ** cv_mac mean: %f ** cv_mac std: %f ** f1bin: %f ** f1mac: %f' 
        % (cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
  
svmallf = pd.DataFrame(temp, columns = ['TP', 'FP', 'TN', 'FN', 'cv_bin mean', 'cv_bin std', 'cv_mac mean', 'cv_man std', 'f1bin', 'f1mac'])
# Out:
# correct/TP: 1056 ** FP: 3 **  TN: 3838 ** FN: 1 ** cv_bin mean: 0.997389 ** cv_bin std: 0.001817 ** cv_mac mean: 0.998350 ** cv_mac std: 0.001148 ** f1bin: 0.998110 ** f1mac: 0.998794
# correct/TP: 1013 ** FP: 6 **  TN: 3878 ** FN: 1 ** cv_bin mean: 0.996623 ** cv_bin std: 0.001824 ** cv_mac mean: 0.997858 ** cv_mac std: 0.001157 ** f1bin: 0.996557 ** f1mac: 0.997828
# correct/TP: 1067 ** FP: 3 **  TN: 3828 ** FN: 0 ** cv_bin mean: 0.997053 ** cv_bin std: 0.001602 ** cv_mac mean: 0.998140 ** cv_mac std: 0.001011 ** f1bin: 0.998596 ** f1mac: 0.999102
# correct/TP: 1010 ** FP: 2 **  TN: 3885 ** FN: 1 ** cv_bin mean: 0.995825 ** cv_bin std: 0.000784 ** cv_mac mean: 0.997351 ** cv_mac std: 0.000498 ** f1bin: 0.998517 ** f1mac: 0.999066
# correct/TP: 1012 ** FP: 6 **  TN: 3879 ** FN: 1 ** cv_bin mean: 0.997749 ** cv_bin std: 0.001636 ** cv_mac mean: 0.998572 ** cv_mac std: 0.001038 ** f1bin: 0.996553 ** f1mac: 0.997826

# %% [markdown]
# LOFO CV

# %%
temp = []

df2test = df2.sample(frac = 0.3)
df2train = df2[~df2.index.isin(df2test.index)]

for fam in set(df1['Fam'].to_list()):
    df1test = df1.loc[df1['Fam'] == fam]
    df1train = df1.loc[~(df1['Fam'] == fam)]
    df1train = df1train.loc[df1train['die'] == 'no']
    
    X_train = pd.concat([df1train.iloc[:,3:], df2train.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_train = pd.concat([df1train.iloc[:,0], df2train.iloc[:,-1]], axis = 0).reset_index(drop = True)

    X_test = pd.concat([df1test.iloc[:,3:], df2test.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_test = pd.concat([df1test.iloc[:,0], df2test.iloc[:,-1]], axis = 0).reset_index(drop = True)
    
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    # Fitting Random Forest Classification to the Training set
    classifier = SVC(kernel = 'linear')
    classifier.fit(X_train, y_train)
    
    # Predicting the Test set results
    y_pred = classifier.predict(X_test)
    
    # Making the Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    #evaluation
    f1bin = f1_score(y_test, y_pred, average='binary')
    f1mac = f1_score(y_test, y_pred, average='macro')
    
    temp.append((fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))

    print('Fam: %s ** total: %d ** correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** f1bin: %f ** f1mac: %f' 
          % (fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))
  
svmlofocv_allf = pd.DataFrame(temp, columns = ['Fam', 'Total', 'Correct/TP', 'FP', 'TN', 'FN', 'f1bin', 'f1mac'])
# Out:
# Fam: togaviridae ** total: 74 ** correct/TP: 74 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.942675 ** f1mac: 0.970853
# Fam: barnaviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: arteriviridae ** total: 48 ** correct/TP: 48 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.914286 ** f1mac: 0.956658
# Fam: chuviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: potyviridae ** total: 340 ** correct/TP: 340 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.986938 ** f1mac: 0.992984
# Fam: nodaviridae ** total: 20 ** correct/TP: 20 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.816327 ** f1mac: 0.907678
# Fam: hypoviridae ** total: 24 ** correct/TP: 24 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.842105 ** f1mac: 0.920568
# Fam: artoviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: filoviridae ** total: 24 ** correct/TP: 24 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.842105 ** f1mac: 0.920568
# Fam: virgaviridae ** total: 82 ** correct/TP: 82 ** FP: 7 **  TN: 4636 ** FN: 0 ** f1bin: 0.959064 ** f1mac: 0.979155
# Fam: mymonaviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: rhabdoviridae ** total: 212 ** correct/TP: 212 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.979215 ** f1mac: 0.989122
# Fam: picornaviridae ** total: 780 ** correct/TP: 771 ** FP: 7 **  TN: 4636 ** FN: 9 ** f1bin: 0.989730 ** f1mac: 0.994004
# Fam: paramyxoviridae ** total: 158 ** correct/TP: 158 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.972308 ** f1mac: 0.985669
# Fam: hepeviridae ** total: 30 ** correct/TP: 30 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.869565 ** f1mac: 0.934298
# Fam: bornaviridae ** total: 24 ** correct/TP: 24 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.842105 ** f1mac: 0.920568
# Fam: marnaviridae ** total: 20 ** correct/TP: 20 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.816327 ** f1mac: 0.907678
# Fam: deltaflexiviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: benyviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: narnaviridae ** total: 72 ** correct/TP: 70 ** FP: 8 **  TN: 4635 ** FN: 2 ** f1bin: 0.933333 ** f1mac: 0.966128
# Fam: matonaviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: alphatetraviridae ** total: 8 ** correct/TP: 8 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.640000 ** f1mac: 0.819515
# Fam: sunviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: iflaviridae ** total: 74 ** correct/TP: 74 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.942675 ** f1mac: 0.970853
# Fam: polycipiviridae ** total: 10 ** correct/TP: 10 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.689655 ** f1mac: 0.844343
# Fam: tymoviridae ** total: 80 ** correct/TP: 80 ** FP: 8 **  TN: 4635 ** FN: 0 ** f1bin: 0.952381 ** f1mac: 0.975759
# Fam: luteoviridae ** total: 100 ** correct/TP: 100 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.956938 ** f1mac: 0.977984
# Fam: closteroviridae ** total: 90 ** correct/TP: 90 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.952381 ** f1mac: 0.975705
# Fam: kitaviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: mesoniviridae ** total: 20 ** correct/TP: 20 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.816327 ** f1mac: 0.907678
# Fam: fimoviridae ** total: 8 ** correct/TP: 8 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.640000 ** f1mac: 0.819515
# Fam: caliciviridae ** total: 320 ** correct/TP: 320 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.986133 ** f1mac: 0.992581
# Fam: coronaviridae ** total: 258 ** correct/TP: 258 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.982857 ** f1mac: 0.990944
# Fam: dicistroviridae ** total: 40 ** correct/TP: 40 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.898876 ** f1mac: 0.948953
# Fam: endornaviridae ** total: 58 ** correct/TP: 58 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.928000 ** f1mac: 0.963515
# Fam: alphaflexiviridae ** total: 110 ** correct/TP: 110 ** FP: 8 **  TN: 4635 ** FN: 0 ** f1bin: 0.964912 ** f1mac: 0.982025
# Fam: roniviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: solemoviridae ** total: 38 ** correct/TP: 38 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.894118 ** f1mac: 0.946574
# Fam: mononiviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: nyamiviridae ** total: 6 ** correct/TP: 3 ** FP: 9 **  TN: 4634 ** FN: 3 ** f1bin: 0.333333 ** f1mac: 0.666020
# Fam: tobaniviridae ** total: 16 ** correct/TP: 16 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.780488 ** f1mac: 0.889759
# Fam: flaviviridae ** total: 340 ** correct/TP: 323 ** FP: 6 **  TN: 4637 ** FN: 17 ** f1bin: 0.965620 ** f1mac: 0.981573
# Fam: carmotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: nairoviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: betaflexiviridae ** total: 220 ** correct/TP: 220 ** FP: 8 **  TN: 4635 ** FN: 0 ** f1bin: 0.982143 ** f1mac: 0.990640
# Fam: leviviridae ** total: 24 ** correct/TP: 24 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.842105 ** f1mac: 0.920568
# Fam: permutotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: hantaviridae ** total: 12 ** correct/TP: 12 ** FP: 8 **  TN: 4635 ** FN: 0 ** f1bin: 0.750000 ** f1mac: 0.874569
# Fam: aspiviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: bromoviridae ** total: 30 ** correct/TP: 30 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.869565 ** f1mac: 0.934298
# Fam: alvernaviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: pneumoviridae ** total: 24 ** correct/TP: 24 ** FP: 7 **  TN: 4636 ** FN: 0 ** f1bin: 0.872727 ** f1mac: 0.935986
# Fam: secoviridae ** total: 36 ** correct/TP: 36 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.888889 ** f1mac: 0.943959
# Fam: peribunyaviridae ** total: 4 ** correct/TP: 4 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.470588 ** f1mac: 0.734809
# Fam: gammaflexiviridae ** total: 2 ** correct/TP: 2 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.307692 ** f1mac: 0.653361
# Fam: astroviridae ** total: 104 ** correct/TP: 104 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.958525 ** f1mac: 0.978778
# Fam: tombusviridae ** total: 132 ** correct/TP: 132 ** FP: 9 **  TN: 4634 ** FN: 0 ** f1bin: 0.967033 ** f1mac: 0.983031

# %%
svmlofocv_allf
# Out:
#                     Fam  Total  Correct/TP  FP    TN  FN     f1bin     f1mac
# 0           togaviridae     74          74   9  4634   0  0.942675  0.970853
# 1          barnaviridae      2           2   9  4634   0  0.307692  0.653361
# 2         arteriviridae     48          48   9  4634   0  0.914286  0.956658
# 3            chuviridae      4           4   9  4634   0  0.470588  0.734809
# 4           potyviridae    340         340   9  4634   0  0.986938  0.992984
# 5           nodaviridae     20          20   9  4634   0  0.816327  0.907678
# 6           hypoviridae     24          24   9  4634   0  0.842105  0.920568
# 7           artoviridae      2           2   9  4634   0  0.307692  0.653361
# 8           filoviridae     24          24   9  4634   0  0.842105  0.920568
# 9          virgaviridae     82          82   7  4636   0  0.959064  0.979155
# 10        mymonaviridae      2           2   9  4634   0  0.307692  0.653361
# 11        rhabdoviridae    212         212   9  4634   0  0.979215  0.989122
# 12       picornaviridae    780         771   7  4636   9  0.989730  0.994004
# 13      paramyxoviridae    158         158   9  4634   0  0.972308  0.985669
# 14          hepeviridae     30          30   9  4634   0  0.869565  0.934298
# 15         bornaviridae     24          24   9  4634   0  0.842105  0.920568
# 16         marnaviridae     20          20   9  4634   0  0.816327  0.907678
# 17    deltaflexiviridae      4           4   9  4634   0  0.470588  0.734809
# 18          benyviridae      2           2   9  4634   0  0.307692  0.653361
# 19         narnaviridae     72          70   8  4635   2  0.933333  0.966128
# 20        matonaviridae      4           4   9  4634   0  0.470588  0.734809
# 21    alphatetraviridae      8           8   9  4634   0  0.640000  0.819515
# 22           sunviridae      2           2   9  4634   0  0.307692  0.653361
# 23          iflaviridae     74          74   9  4634   0  0.942675  0.970853
# 24      polycipiviridae     10          10   9  4634   0  0.689655  0.844343
# 25          tymoviridae     80          80   8  4635   0  0.952381  0.975759
# 26         luteoviridae    100         100   9  4634   0  0.956938  0.977984
# 27      closteroviridae     90          90   9  4634   0  0.952381  0.975705
# 28          kitaviridae      2           2   9  4634   0  0.307692  0.653361
# 29        mesoniviridae     20          20   9  4634   0  0.816327  0.907678
# 30          fimoviridae      8           8   9  4634   0  0.640000  0.819515
# 31        caliciviridae    320         320   9  4634   0  0.986133  0.992581
# 32        coronaviridae    258         258   9  4634   0  0.982857  0.990944
# 33      dicistroviridae     40          40   9  4634   0  0.898876  0.948953
# 34       endornaviridae     58          58   9  4634   0  0.928000  0.963515
# 35    alphaflexiviridae    110         110   8  4635   0  0.964912  0.982025
# 36          roniviridae      4           4   9  4634   0  0.470588  0.734809
# 37        solemoviridae     38          38   9  4634   0  0.894118  0.946574
# 38        mononiviridae      2           2   9  4634   0  0.307692  0.653361
# 39         nyamiviridae      6           3   9  4634   3  0.333333  0.666020
# 40        tobaniviridae     16          16   9  4634   0  0.780488  0.889759
# 41         flaviviridae    340         323   6  4637  17  0.965620  0.981573
# 42    carmotetraviridae      2           2   9  4634   0  0.307692  0.653361
# 43         nairoviridae      2           2   9  4634   0  0.307692  0.653361
# 44     betaflexiviridae    220         220   8  4635   0  0.982143  0.990640
# 45          leviviridae     24          24   9  4634   0  0.842105  0.920568
# 46  permutotetraviridae      2           2   9  4634   0  0.307692  0.653361
# 47         hantaviridae     12          12   8  4635   0  0.750000  0.874569
# 48          aspiviridae      4           4   9  4634   0  0.470588  0.734809
# 49         bromoviridae     30          30   9  4634   0  0.869565  0.934298
# 50       alvernaviridae      2           2   9  4634   0  0.307692  0.653361
# 51        pneumoviridae     24          24   7  4636   0  0.872727  0.935986
# 52          secoviridae     36          36   9  4634   0  0.888889  0.943959
# 53     peribunyaviridae      4           4   9  4634   0  0.470588  0.734809
# 54    gammaflexiviridae      2           2   9  4634   0  0.307692  0.653361
# 55         astroviridae    104         104   9  4634   0  0.958525  0.978778
# 56        tombusviridae    132         132   9  4634   0  0.967033  0.983031

# %% [markdown]
# ## Model performance with 194 features

# %%
l =    ['CAATCG', 'GGTA', 'GTTGA', 'CATACG', 'TGAT', 'GTCGAA', 'CCAATT', 'TGTCGA', 'GTTGAC', 
        'CGGTTA', 'CGATA', 'TAGCGT', 'AAAAAA', 'GGTTGA', 'AAAAA', 'CAAT', 'CGTCAA', 'CGGTAA', 
        'CGTTGA', 'CAAC', 'ACCAAT', 'TTGACG', 'TCAATC', 'GTTG', 'CAATTG', 'CGCAAT', 'GGTT', 
        'TTGTCG', 'TCAA', 'CCAAT', 'ATACGC', 'CGATAG', 'TTGA', 'CATCAA', 'GTTGAT', 'ATACGG', 
        'CGATC', 'GTTGGT', 'GATC', 'CCGATA', 'GTCAAT', 'CGATAA', 'CGCGTT', 'ATCGTA', 'TCGGTT', 
        'ATCAAC', 'ATTGG', 'TCGA', 'GCAATC', 'CAATCT', 'GCGTAC', 'TTCGAC', 'GGTTG', 'TCCAAT', 
        'CGTAGT', 'TTGCG', 'CGGTT', 'CGATTA', 'ACGGTT', 'ATCAAT', 'TTGCGC', 'CAATC', 'CGAT', 
c = [f for f in l if len(f) < 6]
b = [f for f in l if len(f) == 6]
b1 = [f for f in b if f[0] == 'A' or f[0] == 'T']
b2 = [f for f in b if f[0] == 'G' or f[0] == 'C']

df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam'] + c], 
                 pd.read_csv('drive/My Drive/ppnnw6.csv')[b]], axis = 1)

df1 = df1.loc[df1['die'] == 'no']
df1['Gen'] = 1

df2 = pd.concat([pd.read_csv('drive/My Drive/h1w5.csv')[['die'] + c], 
                 pd.read_csv('drive/My Drive/h1w6p1.csv')[b1],
                 pd.read_csv('drive/My Drive/h1w6p2.csv')[b2]], axis = 1)
df2 = df2.loc[df2['die'] == 'no']
df2['Gen'] = 0

data = pd.concat([df1, df2], axis = 0).reset_index(drop = True)

# %%
temp = []
for i in range(5):
  #Splitting features and labels
  X = data.iloc[:, 3:].values.astype(float)
  y = data.iloc[:, 0].values.astype(float)

  # Splitting the dataset into the Training set and Test set
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

  # Feature Scaling
  sc = StandardScaler()
  X_train = sc.fit_transform(X_train)
  X_test = sc.transform(X_test)

  ### Training the decision tree model on the Training set
  classifier = SVC(kernel = 'linear')
  classifier.fit(X_train, y_train)

  # Predicting the Test set results
  y_pred = classifier.predict(X_test)

  # Making the Confusion Matrix
  cm = confusion_matrix(y_test, y_pred)

  #evaluation
  cv_bin = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1')
  cv_mac = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1_macro')
  f1bin = f1_score(y_test, y_pred, average='binary')
  f1mac = f1_score(y_test, y_pred, average='macro')

  temp.append((cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
  print('correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** cv_bin mean: %f ** cv_bin std: %f ** cv_mac mean: %f ** cv_mac std: %f ** f1bin: %f ** f1mac: %f' 
        % (cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
# Out:
# correct/TP: 1051 ** FP: 0 **  TN: 3847 ** FN: 0 ** cv_bin mean: 0.998860 ** cv_bin std: 0.001272 ** cv_mac mean: 0.999279 ** cv_mac std: 0.000804 ** f1bin: 1.000000 ** f1mac: 1.000000
# correct/TP: 1081 ** FP: 0 **  TN: 3817 ** FN: 0 ** cv_bin mean: 0.998850 ** cv_bin std: 0.001281 ** cv_mac mean: 0.999275 ** cv_mac std: 0.000808 ** f1bin: 1.000000 ** f1mac: 1.000000
# correct/TP: 1030 ** FP: 1 **  TN: 3867 ** FN: 0 ** cv_bin mean: 0.998867 ** cv_bin std: 0.000742 ** cv_mac mean: 0.999282 ** cv_mac std: 0.000470 ** f1bin: 0.999515 ** f1mac: 0.999693
# correct/TP: 1020 ** FP: 3 **  TN: 3875 ** FN: 0 ** cv_bin mean: 0.999355 ** cv_bin std: 0.001070 ** cv_mac mean: 0.999591 ** cv_mac std: 0.000678 ** f1bin: 0.998532 ** f1mac: 0.999072
# correct/TP: 1043 ** FP: 0 **  TN: 3855 ** FN: 0 ** cv_bin mean: 0.999025 ** cv_bin std: 0.001077 ** cv_mac mean: 0.999383 ** cv_mac std: 0.000682 ** f1bin: 1.000000 ** f1mac: 1.000000

# %% [markdown]
# LOFO CV

# %%
temp = []

df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam'] + c], 
                 pd.read_csv('drive/My Drive/ppnnw6.csv')[b]], axis = 1)
df1['Gen'] = 1

df2test = df2.sample(frac = 0.3)
df2train = df2[~df2.index.isin(df2test.index)]

for fam in set(df1['Fam'].to_list()):
    df1test = df1.loc[df1['Fam'] == fam]
    df1train = df1.loc[~(df1['Fam'] == fam)]
    df1train = df1train.loc[df1train['die'] == 'no']
    
    X_train = pd.concat([df1train.iloc[:,3:], df2train.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_train = pd.concat([df1train.iloc[:,0], df2train.iloc[:,-1]], axis = 0).reset_index(drop = True)

    X_test = pd.concat([df1test.iloc[:,3:], df2test.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_test = pd.concat([df1test.iloc[:,0], df2test.iloc[:,-1]], axis = 0).reset_index(drop = True)
    
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    # Fitting Random Forest Classification to the Training set
    classifier = SVC(kernel = 'linear')
    classifier.fit(X_train, y_train)
    
    # Predicting the Test set results
    y_pred = classifier.predict(X_test)
    
    # Making the Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    #evaluation
    f1bin = f1_score(y_test, y_pred, average='binary')
    f1mac = f1_score(y_test, y_pred, average='macro')
    
    temp.append((fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))

    print('Fam: %s ** total: %d ** correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** f1bin: %f ** f1mac: %f' 
          % (fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))
  
svmlofocv_194f = pd.DataFrame(temp, columns = ['Fam', 'Total', 'Correct/TP', 'FP', 'TN', 'FN', 'f1bin', 'f1mac'])
# Out:
# Fam: togaviridae ** total: 84 ** correct/TP: 84 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.994083 ** f1mac: 0.996988
# Fam: barnaviridae ** total: 2 ** correct/TP: 2 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.800000 ** f1mac: 0.899946
# Fam: arteriviridae ** total: 48 ** correct/TP: 48 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.989691 ** f1mac: 0.994792
# Fam: chuviridae ** total: 4 ** correct/TP: 4 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.888889 ** f1mac: 0.944391
# Fam: potyviridae ** total: 362 ** correct/TP: 362 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.998621 ** f1mac: 0.999256
# Fam: nodaviridae ** total: 20 ** correct/TP: 20 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.975610 ** f1mac: 0.987751
# Fam: hypoviridae ** total: 24 ** correct/TP: 24 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.979592 ** f1mac: 0.989742
# Fam: artoviridae ** total: 2 ** correct/TP: 2 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.800000 ** f1mac: 0.899946
# Fam: filoviridae ** total: 32 ** correct/TP: 32 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.984615 ** f1mac: 0.992254
# Fam: virgaviridae ** total: 86 ** correct/TP: 86 ** FP: 0 **  TN: 4643 ** FN: 0 ** f1bin: 1.000000 ** f1mac: 1.000000
# Fam: mymonaviridae ** total: 2 ** correct/TP: 2 ** FP: 1 **  TN: 4642 ** FN: 0 ** f1bin: 0.800000 ** f1mac: 0.899946
# Fam
# 33      dicistroviridae     40          40   1  4642   0  0.987654  0.993773
# 34       endornaviridae     60          60   1  4642   0  0.991736  0.995814
# 35    alphaflexiviridae    110         110   0  4643   0  1.000000  1.000000
# 36          roniviridae      4           4   1  4642   0  0.888889  0.944391
# 37        solemoviridae     38          38   1  4642   0  0.987013  0.993453
# 38        mononiviridae      2           2   1  4642   0  0.800000  0.899946
# 39         nyamiviridae      6           6   1  4642   0  0.923077  0.961485
# 40        tobaniviridae     16          16   1  4642   0  0.969697  0.984795
# 41         flaviviridae    390         386   0  4643   4  0.994845  0.997207
# 42    carmotetraviridae      2           2   1  4642   0  0.800000  0.899946
# 43         nairoviridae      2           2   1  4642   0  0.800000  0.899946
# 44     betaflexiviridae    222         222   1  4642   0  0.997753  0.998823
# 45          leviviridae     24          24   1  4642   0  0.979592  0.989742
# 46  permutotetraviridae      2           2   1  4642   0  0.800000  0.899946
# 47         hantaviridae     12          12   1  4642   0  0.960000  0.979946
# 48          aspiviridae      4           4   1  4642   0  0.888889  0.944391
# 49         bromoviridae     30          30   1  4642   0  0.983607  0.991749
# 50       alvernaviridae      2           2   1  4642   0  0.800000  0.899946
# 51        pneumoviridae     30          30   1  4642   0  0.983607  0.991749
# 52          secoviridae     36          36   1  4642   0  0.986301  0.993097
# 53     peribunyaviridae      4           4   1  4642   0  0.888889  0.944391
# 54    gammaflexiviridae      2           2   1  4642   0  0.800000  0.899946
# 55         astroviridae    132         132   1  4642   0  0.996226  0.998059
# 56        tombusviridae    136         136   1  4642   0  0.996337  0.998115

# %% [markdown]
# # 68 Features

# %%
l =    ['TCAATC', 'CCAATT', 'GTTGAC', 'TGAT', 'GGTT', 'GGTTGA', 'GTTGA',
       'TAGCGT', 'CGGTTA', 'TTGACG', 'CGATA', 'CGTCAA', 'CAATCG', 'CGTTGA',
       'GTCGAA', 'GTTG', 'CGGTAA', 'CATACG', 'AAAAAA', 'ACCAAT', 'TCAA',
       'TTGTCG', 'CGATAG', 'AAAAA', 'CAAC', 'ATACGC', 'CAATTG', 'CCAAT',
       'CGCAAT', 'GGTA', 'CAAT', 'TGTCGA', 'CGAT', 'CAATCT', 'GCGTAC', 'GGTTG',
       'TTGA', 'GTTGGT', 'TCCAAT', 'TTGCG', 'ACGGTT', 'CGATTA', 'ATCAAT',
       'GCAATC', 'ATCAAC', 'GTTGAT', 'GTCAAT', 'CGTCGA', 'ATTGG', 'CGTAGT',
       'ATAGCG', 'CCGATA', 'CAATC', 'CATCAA', 'TTCGAC', 'TTGAC', 'TTGCGC',
       'GCGTTA', 'CCGTTA', 'ATACGG', 'CGCGTT', 'CGATC', 'CGATAA', 'ATCGTA',
       'TCGA', 'TCGGTT', 'GATC', 'CGGTT']

c = [f for f in l if len(f) < 6]
b = [f for f in l if len(f) == 6]
b1 = [f for f in b if f[0] == 'A' or f[0] == 'T']
b2 = [f for f in b if f[0] == 'G' or f[0] == 'C']

df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam'] + c], 
                 pd.read_csv('drive/My Drive/ppnnw6.csv')[b]], axis = 1)

df1 = df1.loc[df1['die'] == 'no']
df1['Gen'] = 1

df2 = pd.concat([pd.read_csv('drive/My Drive/h1w5.csv')[['die'] + c], 
                 pd.read_csv('drive/My Drive/h1w6p1.csv')[b1],
                 pd.read_csv('drive/My Drive/h1w6p2.csv')[b2]], axis = 1)
df2 = df2.loc[df2['die'] == 'no']
df2['Gen'] = 0

data = pd.concat([df1, df2], axis = 0).reset_index(drop = True)

# %%
temp = []
for i in range(5):
  #Splitting features and labels
  X = data.iloc[:, 3:].values.astype(float)
  y = data.iloc[:, 0].values.astype(float)

  # Splitting the dataset into the Training set and Test set
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

  # Feature Scaling
  sc = StandardScaler()
  X_train = sc.fit_transform(X_train)
  X_test = sc.transform(X_test)

  ### Training the decision tree model on the Training set
  classifier = SVC(kernel = 'linear')
  classifier.fit(X_train, y_train)

  # Predicting the Test set results
  y_pred = classifier.predict(X_test)

  # Making the Confusion Matrix
  cm = confusion_matrix(y_test, y_pred)

  #evaluation
  cv_bin = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1')
  cv_mac = cross_val_score(classifier, X_train, y_train, cv=10, scoring='f1_macro')
  f1bin = f1_score(y_test, y_pred, average='binary')
  f1mac = f1_score(y_test, y_pred, average='macro')

  temp.append((cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
  print('correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** cv_bin mean: %f ** cv_bin std: %f ** cv_mac mean: %f ** cv_mac std: %f ** f1bin: %f ** f1mac: %f' 
        % (cm[1,1], cm[0,1], cm[0,0], cm[1,0], cv_bin.mean(), cv_bin.std(), cv_mac.mean(), cv_mac.std(), f1bin, f1mac))
# Out:
# correct/TP: 1016 ** FP: 11 **  TN: 3854 ** FN: 17 ** cv_bin mean: 0.984278 ** cv_bin std: 0.004516 ** cv_mac mean: 0.990050 ** cv_mac std: 0.002851 ** f1bin: 0.986408 ** f1mac: 0.991394
# correct/TP: 954 ** FP: 13 **  TN: 3922 ** FN: 9 ** cv_bin mean: 0.985245 ** cv_bin std: 0.005137 ** cv_mac mean: 0.990608 ** cv_mac std: 0.003267 ** f1bin: 0.988601 ** f1mac: 0.992902
# correct/TP: 995 ** FP: 19 **  TN: 3863 ** FN: 21 ** cv_bin mean: 0.986937 ** cv_bin std: 0.005561 ** cv_mac mean: 0.991721 ** cv_mac std: 0.003523 ** f1bin: 0.980296 ** f1mac: 0.987572
# correct/TP: 1037 ** FP: 23 **  TN: 3823 ** FN: 15 ** cv_bin mean: 0.986466 ** cv_bin std: 0.005747 ** cv_mac mean: 0.991448 ** cv_mac std: 0.003630 ** f1bin: 0.982008 ** f1mac: 0.988531
# correct/TP: 982 ** FP: 14 **  TN: 3888 ** FN: 14 ** cv_bin mean: 0.985283 ** cv_bin std: 0.003978 ** cv_mac mean: 0.990653 ** cv_mac std: 0.002525 ** f1bin: 0.985944 ** f1mac: 0.991178

# %%
temp = []

df1 = pd.concat([pd.read_csv('drive/My Drive/ppnnw5.csv')[['Gen', 'die', 'Fam'] + c], 
                 pd.read_csv('drive/My Drive/ppnnw6.csv')[b]], axis = 1)
df1['Gen'] = 1

df2test = df2.sample(frac = 0.3)
df2train = df2[~df2.index.isin(df2test.index)]

for fam in set(df1['Fam'].to_list()):
    df1test = df1.loc[df1['Fam'] == fam]
    df1train = df1.loc[~(df1['Fam'] == fam)]
    df1train = df1train.loc[df1train['die'] == 'no']
    
    X_train = pd.concat([df1train.iloc[:,3:], df2train.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_train = pd.concat([df1train.iloc[:,0], df2train.iloc[:,-1]], axis = 0).reset_index(drop = True)

    X_test = pd.concat([df1test.iloc[:,3:], df2test.iloc[:,1:-1]], axis = 0).reset_index(drop = True)
    y_test = pd.concat([df1test.iloc[:,0], df2test.iloc[:,-1]], axis = 0).reset_index(drop = True)
    
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    # Fitting Random Forest Classification to the Training set
    classifier = SVC(kernel = 'linear')
    classifier.fit(X_train, y_train)
    
    # Predicting the Test set results
    y_pred = classifier.predict(X_test)
    
    # Making the Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    #evaluation
    f1bin = f1_score(y_test, y_pred, average='binary')
    f1mac = f1_score(y_test, y_pred, average='macro')
    
    temp.append((fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))

    print('Fam: %s ** total: %d ** correct/TP: %d ** FP: %d **  TN: %d ** FN: %d ** f1bin: %f ** f1mac: %f' 
          % (fam, len(df1test), cm[1,1], cm[0,1], cm[0,0], cm[1,0], f1bin, f1mac))
  
svmlofocv_68f = pd.DataFrame(temp, columns = ['Fam', 'Total', 'Correct/TP', 'FP', 'TN', 'FN', 'f1bin', 'f1mac'])
# Out:
# Fam: togaviridae ** total: 84 ** correct/TP: 84 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.898396 ** f1mac: 0.948173
# Fam: barnaviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: arteriviridae ** total: 48 ** correct/TP: 48 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.834783 ** f1mac: 0.916366
# Fam: chuviridae ** total: 4 ** correct/TP: 4 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.296296 ** f1mac: 0.647123
# Fam: potyviridae ** total: 362 ** correct/TP: 361 ** FP: 19 **  TN: 4624 ** FN: 1 ** f1bin: 0.973046 ** f1mac: 0.985444
# Fam: nodaviridae ** total: 20 ** correct/TP: 20 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.677966 ** f1mac: 0.837958
# Fam: hypoviridae ** total: 24 ** correct/TP: 24 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.716418 ** f1mac: 0.857184
# Fam: artoviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: filoviridae ** total: 32 ** correct/TP: 32 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.771084 ** f1mac: 0.884517
# Fam: virgaviridae ** total: 86 ** correct/TP: 86 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.900524 ** f1mac: 0.949237
# Fam: mymonaviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: rhabdoviridae ** total: 220 ** correct/TP: 218 ** FP: 18 **  TN: 4625 ** FN: 2 ** f1bin: 0.956140 ** f1mac: 0.976991
# Fam: picornaviridae ** total: 864 ** correct/TP: 851 ** FP: 15 **  TN: 4628 ** FN: 13 ** f1bin: 0.983815 ** f1mac: 0.990400
# Fam: paramyxoviridae ** total: 214 ** correct/TP: 214 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.957494 ** f1mac: 0.977722
# Fam: hepeviridae ** total: 32 ** correct/TP: 32 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.771084 ** f1mac: 0.884517
# Fam: bornaviridae ** total: 24 ** correct/TP: 24 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.716418 ** f1mac: 0.857184
# Fam: marnaviridae ** total: 20 ** correct/TP: 20 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.677966 ** f1mac: 0.837958
# Fam: deltaflexiviridae ** total: 4 ** correct/TP: 4 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.296296 ** f1mac: 0.647123
# Fam: benyviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: narnaviridae ** total: 72 ** correct/TP: 63 ** FP: 15 **  TN: 4628 ** FN: 9 ** f1bin: 0.840000 ** f1mac: 0.918707
# Fam: matonaviridae ** total: 4 ** correct/TP: 4 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.296296 ** f1mac: 0.647123
# Fam: alphatetraviridae ** total: 8 ** correct/TP: 8 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.457143 ** f1mac: 0.727546
# Fam: sunviridae ** total: 2 ** correct/TP: 1 ** FP: 18 **  TN: 4625 ** FN: 1 ** f1bin: 0.095238 ** f1mac: 0.546594
# Fam: iflaviridae ** total: 76 ** correct/TP: 76 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.888889 ** f1mac: 0.943419
# Fam: polycipiviridae ** total: 10 ** correct/TP: 10 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.512821 ** f1mac: 0.755385
# Fam: tymoviridae ** total: 82 ** correct/TP: 67 ** FP: 18 **  TN: 4625 ** FN: 15 ** f1bin: 0.802395 ** f1mac: 0.899420
# Fam: luteoviridae ** total: 106 ** correct/TP: 106 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.917749 ** f1mac: 0.957849
# Fam: closteroviridae ** total: 90 ** correct/TP: 90 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.904523 ** f1mac: 0.951236
# Fam: kitaviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: mesoniviridae ** total: 26 ** correct/TP: 26 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.732394 ** f1mac: 0.865172
# Fam: fimoviridae ** total: 8 ** correct/TP: 5 ** FP: 19 **  TN: 4624 ** FN: 3 ** f1bin: 0.312500 ** f1mac: 0.655063
# Fam: caliciviridae ** total: 1762 ** correct/TP: 1760 ** FP: 19 **  TN: 4624 ** FN: 2 ** f1bin: 0.994069 ** f1mac: 0.995902
# Fam: coronaviridae ** total: 690 ** correct/TP: 690 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.986419 ** f1mac: 0.992184
# Fam: dicistroviridae ** total: 40 ** correct/TP: 40 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.808081 ** f1mac: 0.903015
# Fam: endornaviridae ** total: 60 ** correct/TP: 60 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.863309 ** f1mac: 0.930630
# Fam: alphaflexiviridae ** total: 110 ** correct/TP: 109 ** FP: 19 **  TN: 4624 ** FN: 1 ** f1bin: 0.915966 ** f1mac: 0.956904
# Fam: roniviridae ** total: 4 ** correct/TP: 4 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.296296 ** f1mac: 0.647123
# Fam: solemoviridae ** total: 38 ** correct/TP: 38 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.800000 ** f1mac: 0.898975
# Fam: mononiviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: nyamiviridae ** total: 6 ** correct/TP: 3 ** FP: 17 **  TN: 4626 ** FN: 3 ** f1bin: 0.230769 ** f1mac: 0.614306
# Fam: tobaniviridae ** total: 16 ** correct/TP: 16 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.627451 ** f1mac: 0.812700
# Fam: flaviviridae ** total: 390 ** correct/TP: 338 ** FP: 16 **  TN: 4627 ** FN: 52 ** f1bin: 0.908602 ** f1mac: 0.950654
# Fam: carmotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: nairoviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: betaflexiviridae ** total: 222 ** correct/TP: 221 ** FP: 19 **  TN: 4624 ** FN: 1 ** f1bin: 0.956710 ** f1mac: 0.977276
# Fam: leviviridae ** total: 24 ** correct/TP: 24 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.716418 ** f1mac: 0.857184
# Fam: permutotetraviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: hantaviridae ** total: 12 ** correct/TP: 11 ** FP: 20 **  TN: 4623 ** FN: 1 ** f1bin: 0.511628 ** f1mac: 0.754681
# Fam: aspiviridae ** total: 4 ** correct/TP: 3 ** FP: 20 **  TN: 4623 ** FN: 1 ** f1bin: 0.222222 ** f1mac: 0.609978
# Fam: bromoviridae ** total: 30 ** correct/TP: 30 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.759494 ** f1mac: 0.878722
# Fam: alvernaviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: pneumoviridae ** total: 30 ** correct/TP: 29 ** FP: 16 **  TN: 4627 ** FN: 1 ** f1bin: 0.773333 ** f1mac: 0.885750
# Fam: secoviridae ** total: 36 ** correct/TP: 34 ** FP: 21 **  TN: 4622 ** FN: 2 ** f1bin: 0.747253 ** f1mac: 0.872385
# Fam: peribunyaviridae ** total: 4 ** correct/TP: 3 ** FP: 19 **  TN: 4624 ** FN: 1 ** f1bin: 0.230769 ** f1mac: 0.614306
# Fam: gammaflexiviridae ** total: 2 ** correct/TP: 2 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.173913 ** f1mac: 0.585931
# Fam: astroviridae ** total: 132 ** correct/TP: 132 ** FP: 20 **  TN: 4623 ** FN: 0 ** f1bin: 0.929577 ** f1mac: 0.963710
# Fam: tombusviridae ** total: 136 ** correct/TP: 136 ** FP: 19 **  TN: 4624 ** FN: 0 ** f1bin: 0.934708 ** f1mac: 0.966329

# %%
svmlofocv_68f
# Out:
#                     Fam  Total  Correct/TP  FP    TN  FN     f1bin     f1mac
# 0           togaviridae     84          84  19  4624   0  0.898396  0.948173
# 1          barnaviridae      2           2  19  4624   0  0.173913  0.585931
# 2         arteriviridae     48          48  19  4624   0  0.834783  0.916366
# 3            chuviridae      4           4  19  4624   0  0.296296  0.647123
# 4           potyviridae    362         361  19  4624   1  0.973046  0.985444
# 5           nodaviridae     20          20  19  4624   0  0.677966  0.837958
# 6           hypoviridae     24          24  19  4624   0  0.716418  0.857184
# 7           artoviridae      2           2  19  4624   0  0.173913  0.585931
# 8           filoviridae     32          32  19  4624   0  0.771084  0.884517
# 9          virgaviridae     86          86  19  4624   0  0.900524  0.949237
